# %% [markdown]
# ### Load libraries

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %%
from dotenv import load_dotenv
import os

# %%
import pandas as pd
import numpy as np
import sys
import sqlite3

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KDTree
from sklearn.neighbors import NearestNeighbors

# %%
load_dotenv() # load environment variables
# Out:
# True

# %% [markdown]
# ### Load Spotipy credentials

# %%
client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Create search engine using Spotipy API

# %%
# lookup = 'A lannister always pays his debts'# 'nite fleit'

# %%
lookup = 'Penguin March'# 'nite fleit'

# %%
results = sp.search(q=lookup, limit=10, type="track")

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Penguin+March&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yVtpTbLBVQ2FykO9CETC5'},
#        'href': 'https://api.spotify.com/v1/artists/1yVtpTbLBVQ2FykO9CETC5',
#        'id': '1yVtpTbLBVQ2FykO9CETC5',
#        'name': 'Nite Fleit',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yVtpTbLBVQ2FykO9CETC5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3EodwsFMRVYOVuO6AM54T2'},
#      'href': 'https://api.spotify.com/v1/albums/3EodwsFMRVYOVuO6AM54T2',
#      'id': '3EodwsFMRVYOVuO6AM54T2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab869f4da16377fbe057b492',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab869f4da16377fbe057b492',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab869f4da16377fbe057b492',
#        'width': 64}],
#      'name': 'Steel City Dance Discs Volume 15',
#      'release_date': '2020-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3EodwsFMRVYOVuO6AM54T2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yVtpTbLBVQ2FykO9CETC5'},
#       'href': 'https://api.spotify.com/v1/artists/1yVtpTbLBVQ2FykO9CETC5',
#       'id': '1yVtpTbLBVQ2FykO9CETC5',
#       'name': 'Nite Fleit',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yVtpTbLBVQ2FykO9CETC5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258347,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBJX31964024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SkO0tOC6zsf7YgudT5Obi'},
#     'href': 'https://api.spotify.com/v1/tracks/1SkO0tOC6zsf7YgudT5Obi',
#     'id': '1SkO0tOC6zsf7YgudT5Obi',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e42a9c8e8dd79168ed3775fcda18c43f69e63fbb?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1SkO0tOC6zsf7YgudT5Obi'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lrt7LngdzxaQtLIXMraSR'},
#        'href': 'https://api.spotify.com/v1/artists/6lrt7LngdzxaQtLIXMraSR',
#        'id': '6lrt7LngdzxaQtLIXMraSR',
#        'name': 'Joe Rogan',
#        'type': 'artist',
#        'uri': 'spotify:artist:6lrt7LngdzxaQtLIXMraSR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4BZtfFxZclfMIcCMyqUjIZ'},
#      'href': 'https://api.spotify.com/v1/albums/4BZtfFxZclfMIcCMyqUjIZ',
#      'id': '4BZtfFxZclfMIcCMyqUjIZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f0d879c2deeed1647f8f920',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f0d879c2deeed1647f8f920',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f0d879c2deeed1647f8f920',
#        'width': 64}],
#      'name': 'Shiny Happy Jihad',
#      'release_date': '2007-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:4BZtfFxZclfMIcCMyqUjIZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lrt7LngdzxaQtLIXMraSR'},
#       'href': 'https://api.spotify.com/v1/artists/6lrt7LngdzxaQtLIXMraSR',
#       'id': '6lrt7LngdzxaQtLIXMraSR',
#       'name': 'Joe Rogan',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lrt7LngdzxaQtLIXMraSR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 392240,
#     'explicit': False,
#     'external_ids': {'isrc': 'US85P0749009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6faeYVglMNa976bsK1HhPs'},
#     'href': 'https://api.spotify.com/v1/tracks/6faeYVglMNa976bsK1HhPs',
#     'id': '6faeYVglMNa976bsK1HhPs',
#     'is_local': False,
#     'name': 'Boycotting and People Who Like Animals More than People, March of the Penguins',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/553c922ede96cdb29d399a65184fbfd4596a22e7?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6faeYVglMNa976bsK1HhPs'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pym9RQGAEdoXHiYpcDqwt'},
#        'href': 'https://api.spotify.com/v1/artists/6pym9RQGAEdoXHiYpcDqwt',
#        'id': '6pym9RQGAEdoXHiYpcDqwt',
#        'name': 'Alexander Ruda',
#        'type': 'artist',
#        'uri': 'spotify:artist:6pym9RQGAEdoXHiYpcDqwt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3fen1XLpniOT7QzzpOB5Gn'},
#      'href': 'https://api.spotify.com/v1/albums/3fen1XLpniOT7QzzpOB5Gn',
#      'id': '3fen1XLpniOT7QzzpOB5Gn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273856fec4f1ec3710f492521c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02856fec4f1ec3710f492521c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851856fec4f1ec3710f492521c9',
#        'width': 64}],
#      'name': 'Waves',
#      'release_date': '2020-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3fen1XLpniOT7QzzpOB5Gn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pym9RQGAEdoXHiYpcDqwt'},
#       'href': 'https://api.spotify.com/v1/artists/6pym9RQGAEdoXHiYpcDqwt',
#       'id': '6pym9RQGAEdoXHiYpcDqwt',
#       'name': 'Alexander Ruda',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pym9RQGAEdoXHiYpcDqwt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 86465,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZLQR2035526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FRINcHuHYCcS4wprUyZT5'},
#     'href': 'https://api.spotify.com/v1/tracks/2FRINcHuHYCcS4wprUyZT5',
#     'id': '2FRINcHuHYCcS4wprUyZT5',
#     'is_local': False,
#     'name': 'March of the Penguins',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3869074ef25ad2fd66120ea054e1439dd0d006ae?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2FRINcHuHYCcS4wprUyZT5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1BxqJ6pOCi8mkSjCbFYjpW'},
#        'href': 'https://api.spotify.com/v1/artists/1BxqJ6pOCi8mkSjCbFYjpW',
#        'id': '1BxqJ6pOCi8mkSjCbFYjpW',
#        'name': 'Harry Gregson-Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:1BxqJ6pOCi8mkSjCbFYjpW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lnDyf5b6lGAlBfAU2ak4k'},
#      'href': 'https://api.spotify.com/v1/albums/3lnDyf5b6lGAlBfAU2ak4k',
#      'id': '3lnDyf5b6lGAlBfAU2ak4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337b575b6515e99c6014a019a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237b575b6515e99c6014a019a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137b575b6515e99c6014a019a',
#        'width': 64}],
#      'name': 'Penguins (Original Motion Picture Soundtrack)',
#      'release_date': '2019-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3lnDyf5b6lGAlBfAU2ak4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1BxqJ6pOCi8mkSjCbFYjpW'},
#       'href': 'https://api.spotify.com/v1/artists/1BxqJ6pOCi8mkSjCbFYjpW',
#       'id': '1BxqJ6pOCi8mkSjCbFYjpW',
#       'name': 'Harry Gregson-Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:1BxqJ6pOCi8mkSjCbFYjpW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 124441,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11992905'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5swl3l8HLN0ZqOEPS0gKS1'},
#     'href': 'https://api.spotify.com/v1/tracks/5swl3l8HLN0ZqOEPS0gKS1',
#     'id': '5swl3l8HLN0ZqOEPS0gKS1',
#     'is_local': False,
#     'name': 'The Penguin March',
#     'popularity': 16,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5swl3l8HLN0ZqOEPS0gKS1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fs2V0SKIuMWWXySuyV5Wl'},
#        'href': 'https://api.spotify.com/v1/artists/3Fs2V0SKIuMWWXySuyV5Wl',
#        'id': '3Fs2V0SKIuMWWXySuyV5Wl',
#        'name': 'Zilla',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Fs2V0SKIuMWWXySuyV5Wl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5grr6d3xwNPpQTbHE0az5x'},
#      'href': 'https://api.spotify.com/v1/albums/5grr6d3xwNPpQTbHE0az5x',
#      'id': '5grr6d3xwNPpQTbHE0az5x',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9d1195a941981904424824b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9d1195a941981904424824b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9d1195a941981904424824b',
#        'width': 64}],
#      'name': 'all iZ',
#      'release_date': '2006-09-05',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5grr6d3xwNPpQTbHE0az5x'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fs2V0SKIuMWWXySuyV5Wl'},
#       'href': 'https://api.spotify.com/v1/artists/3Fs2V0SKIuMWWXySuyV5Wl',
#       'id': '3Fs2V0SKIuMWWXySuyV5Wl',
#       'name': 'Zilla',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fs2V0SKIuMWWXySuyV5Wl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JJNaxieum9cRnlVQWEc08'},
#       'href': 'https://api.spotify.com/v1/artists/5JJNaxieum9cRnlVQWEc08',
#       'id': '5JJNaxieum9cRnlVQWEc08',
#       'name': 'Michael Travis of The String Cheese Incident',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JJNaxieum9cRnlVQWEc08'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 429093,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSGI0620103'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5pliJfbfqjZuPCFTIpXFKJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5pliJfbfqjZuPCFTIpXFKJ',
#     'id': '5pliJfbfqjZuPCFTIpXFKJ',
#     'is_local': False,
#     'name': 'Funeral March of the Penguin Mafia',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/692b267088b2f1bae489d672542006cda96fee3b?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5pliJfbfqjZuPCFTIpXFKJ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18bimFUuK9oHP6wqLZaJ3H'},
#        'href': 'https://api.spotify.com/v1/artists/18bimFUuK9oHP6wqLZaJ3H',
#        'id': '18bimFUuK9oHP6wqLZaJ3H',
#        'name': 'Faximile',
#        'type': 'artist',
#        'uri': 'spotify:artist:18bimFUuK9oHP6wqLZaJ3H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7oBLDHwBoFgbsOimU3nVZp'},
#      'href': 'https://api.spotify.com/v1/albums/7oBLDHwBoFgbsOimU3nVZp',
#      'id': '7oBLDHwBoFgbsOimU3nVZp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fff701f6c90efd3e365353b4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fff701f6c90efd3e365353b4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fff701f6c90efd3e365353b4',
#        'width': 64}],
#      'name': 'Faximile',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:7oBLDHwBoFgbsOimU3nVZp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18bimFUuK9oHP6wqLZaJ3H'},
#       'href': 'https://api.spotify.com/v1/artists/18bimFUuK9oHP6wqLZaJ3H',
#       'id': '18bimFUuK9oHP6wqLZaJ3H',
#       'name': 'Faximile',
#       'type': 'artist',
#       'uri': 'spotify:artist:18bimFUuK9oHP6wqLZaJ3H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 423995,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEZ651714462'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64MEH8gGYBXREk5SNC6lfG'},
#     'href': 'https://api.spotify.com/v1/tracks/64MEH8gGYBXREk5SNC6lfG',
#     'id': '64MEH8gGYBXREk5SNC6lfG',
#     'is_local': False,
#     'name': 'Marching Penguins',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/265c71b64209b51f23754c4f6ad5d3c537523f07?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:64MEH8gGYBXREk5SNC6lfG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y28NzIaxov52VtUOT0aHS'},
#        'href': 'https://api.spotify.com/v1/artists/1Y28NzIaxov52VtUOT0aHS',
#        'id': '1Y28NzIaxov52VtUOT0aHS',
#        'name': 'Smile Company',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Y28NzIaxov52VtUOT0aHS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qVkqrLhpUF0PEwAAcukPZ'},
#      'href': 'https://api.spotify.com/v1/albums/6qVkqrLhpUF0PEwAAcukPZ',
#      'id': '6qVkqrLhpUF0PEwAAcukPZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27394e531819463b485c9fd9bc7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0294e531819463b485c9fd9bc7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485194e531819463b485c9fd9bc7',
#        'width': 64}],
#      'name': 'Story Time',
#      'release_date': '2011-06-13',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6qVkqrLhpUF0PEwAAcukPZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y28NzIaxov52VtUOT0aHS'},
#       'href': 'https://api.spotify.com/v1/artists/1Y28NzIaxov52VtUOT0aHS',
#       'id': '1Y28NzIaxov52VtUOT0aHS',
#       'name': 'Smile Company',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Y28NzIaxov52VtUOT0aHS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 71640,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V80677257'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/02NTWbBbZjfucKZw9S3wqz'},
#     'href': 'https://api.spotify.com/v1/tracks/02NTWbBbZjfucKZw9S3wqz',
#     'id': '02NTWbBbZjfucKZw9S3wqz',
#     'is_local': False,
#     'name': 'Marching Penguins',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/deb44cc332c985e7b5e0c3bbda5ba52b668066f7?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:02NTWbBbZjfucKZw9S3wqz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5U2fHmf4w4MiTVDxEPUZzJ'},
#      'href': 'https://api.spotify.com/v1/albums/5U2fHmf4w4MiTVDxEPUZzJ',
#      'id': '5U2fHmf4w4MiTVDxEPUZzJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c845cb5e7b93781e90c569ae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c845cb5e7b93781e90c569ae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c845cb5e7b93781e90c569ae',
#        'width': 64}],
#      'name': "Virginia Band & Orchestra Directors' Association 2020 District XI Middle School Band Assessment Lake Braddock Middle School",
#      'release_date': '2020-03-17',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5U2fHmf4w4MiTVDxEPUZzJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5IpTRpaFLMAFEb3c6P93Bc'},
#       'href': 'https://api.spotify.com/v1/artists/5IpTRpaFLMAFEb3c6P93Bc',
#       'id': '5IpTRpaFLMAFEb3c6P93Bc',
#       'name': 'Albert Oliver Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5IpTRpaFLMAFEb3c6P93Bc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EJ9jDtJezoPnzN6pssZvw'},
#       'href': 'https://api.spotify.com/v1/artists/1EJ9jDtJezoPnzN6pssZvw',
#       'id': '1EJ9jDtJezoPnzN6pssZvw',
#       'name': 'Lake Braddock Bruin Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:1EJ9jDtJezoPnzN6pssZvw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WC6NF0pnzZHEy5esg3zhZ'},
#       'href': 'https://api.spotify.com/v1/artists/6WC6NF0pnzZHEy5esg3zhZ',
#       'id': '6WC6NF0pnzZHEy5esg3zhZ',
#       'name': 'Jason Miller',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WC6NF0pnzZHEy5esg3zhZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 155413,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBWUL2048685'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21jYiqmRjE294RVHUKvqLX'},
#     'href': 'https://api.spotify.com/v1/tracks/21jYiqmRjE294RVHUKvqLX',
#     'id': '21jYiqmRjE294RVHUKvqLX',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0085db7e5b155067a14efa3973c6c3d440ca3b4b?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:21jYiqmRjE294RVHUKvqLX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Z4uvjnOZVHec4E4gbWolx'},
#        'href': 'https://api.spotify.com/v1/artists/6Z4uvjnOZVHec4E4gbWolx',
#        'id': '6Z4uvjnOZVHec4E4gbWolx',
#        'name': 'Udi Harpaz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Z4uvjnOZVHec4E4gbWolx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uIQGbbTR5yGS3mSnzlfen'},
#      'href': 'https://api.spotify.com/v1/albums/3uIQGbbTR5yGS3mSnzlfen',
#      'id': '3uIQGbbTR5yGS3mSnzlfen',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e4903912ce70058bcd0f501',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e4903912ce70058bcd0f501',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e4903912ce70058bcd0f501',
#        'width': 64}],
#      'name': 'Filmscore Excursions',
#      'release_date': '2008-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3uIQGbbTR5yGS3mSnzlfen'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Z4uvjnOZVHec4E4gbWolx'},
#       'href': 'https://api.spotify.com/v1/artists/6Z4uvjnOZVHec4E4gbWolx',
#       'id': '6Z4uvjnOZVHec4E4gbWolx',
#       'name': 'Udi Harpaz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Z4uvjnOZVHec4E4gbWolx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 146093,
#     'explicit': False,
#     'external_ids': {'isrc': 'US1ST1401863'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ATuBhVdGfH1w2sdFaM42E'},
#     'href': 'https://api.spotify.com/v1/tracks/0ATuBhVdGfH1w2sdFaM42E',
#     'id': '0ATuBhVdGfH1w2sdFaM42E',
#     'is_local': False,
#     'name': 'Penguins March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cd056ed54117d11565663492b0b1669b8f710876?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0ATuBhVdGfH1w2sdFaM42E'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FE7rH0UfJwX8ZX1wWNRoJ'},
#        'href': 'https://api.spotify.com/v1/artists/7FE7rH0UfJwX8ZX1wWNRoJ',
#        'id': '7FE7rH0UfJwX8ZX1wWNRoJ',
#        'name': 'Tetsuro Ichii',
#        'type': 'artist',
#        'uri': 'spotify:artist:7FE7rH0UfJwX8ZX1wWNRoJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XbOg1ImTQ3P8WmLe725Ms'},
#      'href': 'https://api.spotify.com/v1/albums/4XbOg1ImTQ3P8WmLe725Ms',
#      'id': '4XbOg1ImTQ3P8WmLe725Ms',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733be9eb2e4510f9754ddd15af',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023be9eb2e4510f9754ddd15af',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513be9eb2e4510f9754ddd15af',
#        'width': 64}],
#      'name': 'Eternal Birth',
#      'release_date': '2018-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4XbOg1ImTQ3P8WmLe725Ms'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O1mntSFn7fax54Sbiz6mF'},
#       'href': 'https://api.spotify.com/v1/artists/4O1mntSFn7fax54Sbiz6mF',
#       'id': '4O1mntSFn7fax54Sbiz6mF',
#       'name': 'Ichii Tetsuro',
#       'type': 'artist',
#       'uri': 'spotify:artist:4O1mntSFn7fax54Sbiz6mF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 97359,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCJPH1807598'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/33KMEmLfcvfWd1IaRI9Qzn'},
#     'href': 'https://api.spotify.com/v1/tracks/33KMEmLfcvfWd1IaRI9Qzn',
#     'id': '33KMEmLfcvfWd1IaRI9Qzn',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8be052e3eecce4e82603656495258f74254246a5?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:33KMEmLfcvfWd1IaRI9Qzn'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Penguin+March&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 66}}

# %%
for i, track in enumerate(results['tracks']['items']):
    print(' ', i, track['name'],'-', track['artists'][0]['name'], '-', track['id'],
         '-', track['external_urls']['spotify'], '-', track['explicit'])
# Out:
#   0 Penguin March - Nite Fleit - 1SkO0tOC6zsf7YgudT5Obi - https://open.spotify.com/track/1SkO0tOC6zsf7YgudT5Obi - False
#   1 Boycotting and People Who Like Animals More than People, March of the Penguins - Joe Rogan - 6faeYVglMNa976bsK1HhPs - https://open.spotify.com/track/6faeYVglMNa976bsK1HhPs - False
#   2 March of the Penguins - Alexander Ruda - 2FRINcHuHYCcS4wprUyZT5 - https://open.spotify.com/track/2FRINcHuHYCcS4wprUyZT5 - False
#   3 The Penguin March - Harry Gregson-Williams - 5swl3l8HLN0ZqOEPS0gKS1 - https://open.spotify.com/track/5swl3l8HLN0ZqOEPS0gKS1 - False
#   4 Funeral March of the Penguin Mafia - Zilla - 5pliJfbfqjZuPCFTIpXFKJ - https://open.spotify.com/track/5pliJfbfqjZuPCFTIpXFKJ - False
#   5 Marching Penguins - Faximile - 64MEH8gGYBXREk5SNC6lfG - https://open.spotify.com/track/64MEH8gGYBXREk5SNC6lfG - False
#   6 Marching Penguins - Smile Company - 02NTWbBbZjfucKZw9S3wqz - https://open.spotify.com/track/02NTWbBbZjfucKZw9S3wqz - False
#   7 Penguin March - Albert Oliver Davis - 21jYiqmRjE294RVHUKvqLX - https://open.spotify.com/track/21jYiqmRjE294RVHUKvqLX - False
#   8 Penguins March - Udi Harpaz - 0ATuBhVdGfH1w2sdFaM42E - https://open.spotify.com/track/0ATuBhVdGfH1w2sdFaM42E - False
#   9 Penguin March - Ichii Tetsuro - 33KMEmLfcvfWd1IaRI9Qzn - https://open.spotify.com/track/33KMEmLfcvfWd1IaRI9Qzn - False

# %%
song_id = '0gjfdXCV6yrwhP23NVx1Fm'

# %%
song_id
# Out:
# '0gjfdXCV6yrwhP23NVx1Fm'

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Penguin+March&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yVtpTbLBVQ2FykO9CETC5'},
#        'href': 'https://api.spotify.com/v1/artists/1yVtpTbLBVQ2FykO9CETC5',
#        'id': '1yVtpTbLBVQ2FykO9CETC5',
#        'name': 'Nite Fleit',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yVtpTbLBVQ2FykO9CETC5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3EodwsFMRVYOVuO6AM54T2'},
#      'href': 'https://api.spotify.com/v1/albums/3EodwsFMRVYOVuO6AM54T2',
#      'id': '3EodwsFMRVYOVuO6AM54T2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab869f4da16377fbe057b492',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab869f4da16377fbe057b492',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab869f4da16377fbe057b492',
#        'width': 64}],
#      'name': 'Steel City Dance Discs Volume 15',
#      'release_date': '2020-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:3EodwsFMRVYOVuO6AM54T2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yVtpTbLBVQ2FykO9CETC5'},
#       'href': 'https://api.spotify.com/v1/artists/1yVtpTbLBVQ2FykO9CETC5',
#       'id': '1yVtpTbLBVQ2FykO9CETC5',
#       'name': 'Nite Fleit',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yVtpTbLBVQ2FykO9CETC5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258347,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBJX31964024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1SkO0tOC6zsf7YgudT5Obi'},
#     'href': 'https://api.spotify.com/v1/tracks/1SkO0tOC6zsf7YgudT5Obi',
#     'id': '1SkO0tOC6zsf7YgudT5Obi',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e42a9c8e8dd79168ed3775fcda18c43f69e63fbb?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1SkO0tOC6zsf7YgudT5Obi'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lrt7LngdzxaQtLIXMraSR'},
#        'href': 'https://api.spotify.com/v1/artists/6lrt7LngdzxaQtLIXMraSR',
#        'id': '6lrt7LngdzxaQtLIXMraSR',
#        'name': 'Joe Rogan',
#        'type': 'artist',
#        'uri': 'spotify:artist:6lrt7LngdzxaQtLIXMraSR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4BZtfFxZclfMIcCMyqUjIZ'},
#      'href': 'https://api.spotify.com/v1/albums/4BZtfFxZclfMIcCMyqUjIZ',
#      'id': '4BZtfFxZclfMIcCMyqUjIZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f0d879c2deeed1647f8f920',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f0d879c2deeed1647f8f920',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f0d879c2deeed1647f8f920',
#        'width': 64}],
#      'name': 'Shiny Happy Jihad',
#      'release_date': '2007-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:4BZtfFxZclfMIcCMyqUjIZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lrt7LngdzxaQtLIXMraSR'},
#       'href': 'https://api.spotify.com/v1/artists/6lrt7LngdzxaQtLIXMraSR',
#       'id': '6lrt7LngdzxaQtLIXMraSR',
#       'name': 'Joe Rogan',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lrt7LngdzxaQtLIXMraSR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 392240,
#     'explicit': False,
#     'external_ids': {'isrc': 'US85P0749009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6faeYVglMNa976bsK1HhPs'},
#     'href': 'https://api.spotify.com/v1/tracks/6faeYVglMNa976bsK1HhPs',
#     'id': '6faeYVglMNa976bsK1HhPs',
#     'is_local': False,
#     'name': 'Boycotting and People Who Like Animals More than People, March of the Penguins',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/553c922ede96cdb29d399a65184fbfd4596a22e7?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6faeYVglMNa976bsK1HhPs'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pym9RQGAEdoXHiYpcDqwt'},
#        'href': 'https://api.spotify.com/v1/artists/6pym9RQGAEdoXHiYpcDqwt',
#        'id': '6pym9RQGAEdoXHiYpcDqwt',
#        'name': 'Alexander Ruda',
#        'type': 'artist',
#        'uri': 'spotify:artist:6pym9RQGAEdoXHiYpcDqwt'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3fen1XLpniOT7QzzpOB5Gn'},
#      'href': 'https://api.spotify.com/v1/albums/3fen1XLpniOT7QzzpOB5Gn',
#      'id': '3fen1XLpniOT7QzzpOB5Gn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273856fec4f1ec3710f492521c9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02856fec4f1ec3710f492521c9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851856fec4f1ec3710f492521c9',
#        'width': 64}],
#      'name': 'Waves',
#      'release_date': '2020-06-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3fen1XLpniOT7QzzpOB5Gn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pym9RQGAEdoXHiYpcDqwt'},
#       'href': 'https://api.spotify.com/v1/artists/6pym9RQGAEdoXHiYpcDqwt',
#       'id': '6pym9RQGAEdoXHiYpcDqwt',
#       'name': 'Alexander Ruda',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pym9RQGAEdoXHiYpcDqwt'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 86465,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZLQR2035526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FRINcHuHYCcS4wprUyZT5'},
#     'href': 'https://api.spotify.com/v1/tracks/2FRINcHuHYCcS4wprUyZT5',
#     'id': '2FRINcHuHYCcS4wprUyZT5',
#     'is_local': False,
#     'name': 'March of the Penguins',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3869074ef25ad2fd66120ea054e1439dd0d006ae?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2FRINcHuHYCcS4wprUyZT5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1BxqJ6pOCi8mkSjCbFYjpW'},
#        'href': 'https://api.spotify.com/v1/artists/1BxqJ6pOCi8mkSjCbFYjpW',
#        'id': '1BxqJ6pOCi8mkSjCbFYjpW',
#        'name': 'Harry Gregson-Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:1BxqJ6pOCi8mkSjCbFYjpW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3lnDyf5b6lGAlBfAU2ak4k'},
#      'href': 'https://api.spotify.com/v1/albums/3lnDyf5b6lGAlBfAU2ak4k',
#      'id': '3lnDyf5b6lGAlBfAU2ak4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337b575b6515e99c6014a019a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237b575b6515e99c6014a019a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137b575b6515e99c6014a019a',
#        'width': 64}],
#      'name': 'Penguins (Original Motion Picture Soundtrack)',
#      'release_date': '2019-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:3lnDyf5b6lGAlBfAU2ak4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1BxqJ6pOCi8mkSjCbFYjpW'},
#       'href': 'https://api.spotify.com/v1/artists/1BxqJ6pOCi8mkSjCbFYjpW',
#       'id': '1BxqJ6pOCi8mkSjCbFYjpW',
#       'name': 'Harry Gregson-Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:1BxqJ6pOCi8mkSjCbFYjpW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 124441,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11992905'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5swl3l8HLN0ZqOEPS0gKS1'},
#     'href': 'https://api.spotify.com/v1/tracks/5swl3l8HLN0ZqOEPS0gKS1',
#     'id': '5swl3l8HLN0ZqOEPS0gKS1',
#     'is_local': False,
#     'name': 'The Penguin March',
#     'popularity': 16,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5swl3l8HLN0ZqOEPS0gKS1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fs2V0SKIuMWWXySuyV5Wl'},
#        'href': 'https://api.spotify.com/v1/artists/3Fs2V0SKIuMWWXySuyV5Wl',
#        'id': '3Fs2V0SKIuMWWXySuyV5Wl',
#        'name': 'Zilla',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Fs2V0SKIuMWWXySuyV5Wl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5grr6d3xwNPpQTbHE0az5x'},
#      'href': 'https://api.spotify.com/v1/albums/5grr6d3xwNPpQTbHE0az5x',
#      'id': '5grr6d3xwNPpQTbHE0az5x',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9d1195a941981904424824b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9d1195a941981904424824b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9d1195a941981904424824b',
#        'width': 64}],
#      'name': 'all iZ',
#      'release_date': '2006-09-05',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5grr6d3xwNPpQTbHE0az5x'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Fs2V0SKIuMWWXySuyV5Wl'},
#       'href': 'https://api.spotify.com/v1/artists/3Fs2V0SKIuMWWXySuyV5Wl',
#       'id': '3Fs2V0SKIuMWWXySuyV5Wl',
#       'name': 'Zilla',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Fs2V0SKIuMWWXySuyV5Wl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JJNaxieum9cRnlVQWEc08'},
#       'href': 'https://api.spotify.com/v1/artists/5JJNaxieum9cRnlVQWEc08',
#       'id': '5JJNaxieum9cRnlVQWEc08',
#       'name': 'Michael Travis of The String Cheese Incident',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JJNaxieum9cRnlVQWEc08'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 429093,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSGI0620103'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5pliJfbfqjZuPCFTIpXFKJ'},
#     'href': 'https://api.spotify.com/v1/tracks/5pliJfbfqjZuPCFTIpXFKJ',
#     'id': '5pliJfbfqjZuPCFTIpXFKJ',
#     'is_local': False,
#     'name': 'Funeral March of the Penguin Mafia',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/692b267088b2f1bae489d672542006cda96fee3b?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5pliJfbfqjZuPCFTIpXFKJ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18bimFUuK9oHP6wqLZaJ3H'},
#        'href': 'https://api.spotify.com/v1/artists/18bimFUuK9oHP6wqLZaJ3H',
#        'id': '18bimFUuK9oHP6wqLZaJ3H',
#        'name': 'Faximile',
#        'type': 'artist',
#        'uri': 'spotify:artist:18bimFUuK9oHP6wqLZaJ3H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7oBLDHwBoFgbsOimU3nVZp'},
#      'href': 'https://api.spotify.com/v1/albums/7oBLDHwBoFgbsOimU3nVZp',
#      'id': '7oBLDHwBoFgbsOimU3nVZp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fff701f6c90efd3e365353b4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fff701f6c90efd3e365353b4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fff701f6c90efd3e365353b4',
#        'width': 64}],
#      'name': 'Faximile',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:7oBLDHwBoFgbsOimU3nVZp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18bimFUuK9oHP6wqLZaJ3H'},
#       'href': 'https://api.spotify.com/v1/artists/18bimFUuK9oHP6wqLZaJ3H',
#       'id': '18bimFUuK9oHP6wqLZaJ3H',
#       'name': 'Faximile',
#       'type': 'artist',
#       'uri': 'spotify:artist:18bimFUuK9oHP6wqLZaJ3H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 423995,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEZ651714462'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64MEH8gGYBXREk5SNC6lfG'},
#     'href': 'https://api.spotify.com/v1/tracks/64MEH8gGYBXREk5SNC6lfG',
#     'id': '64MEH8gGYBXREk5SNC6lfG',
#     'is_local': False,
#     'name': 'Marching Penguins',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/265c71b64209b51f23754c4f6ad5d3c537523f07?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:64MEH8gGYBXREk5SNC6lfG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y28NzIaxov52VtUOT0aHS'},
#        'href': 'https://api.spotify.com/v1/artists/1Y28NzIaxov52VtUOT0aHS',
#        'id': '1Y28NzIaxov52VtUOT0aHS',
#        'name': 'Smile Company',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Y28NzIaxov52VtUOT0aHS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qVkqrLhpUF0PEwAAcukPZ'},
#      'href': 'https://api.spotify.com/v1/albums/6qVkqrLhpUF0PEwAAcukPZ',
#      'id': '6qVkqrLhpUF0PEwAAcukPZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27394e531819463b485c9fd9bc7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0294e531819463b485c9fd9bc7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485194e531819463b485c9fd9bc7',
#        'width': 64}],
#      'name': 'Story Time',
#      'release_date': '2011-06-13',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6qVkqrLhpUF0PEwAAcukPZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Y28NzIaxov52VtUOT0aHS'},
#       'href': 'https://api.spotify.com/v1/artists/1Y28NzIaxov52VtUOT0aHS',
#       'id': '1Y28NzIaxov52VtUOT0aHS',
#       'name': 'Smile Company',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Y28NzIaxov52VtUOT0aHS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 71640,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V80677257'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/02NTWbBbZjfucKZw9S3wqz'},
#     'href': 'https://api.spotify.com/v1/tracks/02NTWbBbZjfucKZw9S3wqz',
#     'id': '02NTWbBbZjfucKZw9S3wqz',
#     'is_local': False,
#     'name': 'Marching Penguins',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/deb44cc332c985e7b5e0c3bbda5ba52b668066f7?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:02NTWbBbZjfucKZw9S3wqz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5U2fHmf4w4MiTVDxEPUZzJ'},
#      'href': 'https://api.spotify.com/v1/albums/5U2fHmf4w4MiTVDxEPUZzJ',
#      'id': '5U2fHmf4w4MiTVDxEPUZzJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c845cb5e7b93781e90c569ae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c845cb5e7b93781e90c569ae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c845cb5e7b93781e90c569ae',
#        'width': 64}],
#      'name': "Virginia Band & Orchestra Directors' Association 2020 District XI Middle School Band Assessment Lake Braddock Middle School",
#      'release_date': '2020-03-17',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5U2fHmf4w4MiTVDxEPUZzJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5IpTRpaFLMAFEb3c6P93Bc'},
#       'href': 'https://api.spotify.com/v1/artists/5IpTRpaFLMAFEb3c6P93Bc',
#       'id': '5IpTRpaFLMAFEb3c6P93Bc',
#       'name': 'Albert Oliver Davis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5IpTRpaFLMAFEb3c6P93Bc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1EJ9jDtJezoPnzN6pssZvw'},
#       'href': 'https://api.spotify.com/v1/artists/1EJ9jDtJezoPnzN6pssZvw',
#       'id': '1EJ9jDtJezoPnzN6pssZvw',
#       'name': 'Lake Braddock Bruin Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:1EJ9jDtJezoPnzN6pssZvw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WC6NF0pnzZHEy5esg3zhZ'},
#       'href': 'https://api.spotify.com/v1/artists/6WC6NF0pnzZHEy5esg3zhZ',
#       'id': '6WC6NF0pnzZHEy5esg3zhZ',
#       'name': 'Jason Miller',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WC6NF0pnzZHEy5esg3zhZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 155413,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBWUL2048685'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21jYiqmRjE294RVHUKvqLX'},
#     'href': 'https://api.spotify.com/v1/tracks/21jYiqmRjE294RVHUKvqLX',
#     'id': '21jYiqmRjE294RVHUKvqLX',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0085db7e5b155067a14efa3973c6c3d440ca3b4b?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:21jYiqmRjE294RVHUKvqLX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Z4uvjnOZVHec4E4gbWolx'},
#        'href': 'https://api.spotify.com/v1/artists/6Z4uvjnOZVHec4E4gbWolx',
#        'id': '6Z4uvjnOZVHec4E4gbWolx',
#        'name': 'Udi Harpaz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Z4uvjnOZVHec4E4gbWolx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uIQGbbTR5yGS3mSnzlfen'},
#      'href': 'https://api.spotify.com/v1/albums/3uIQGbbTR5yGS3mSnzlfen',
#      'id': '3uIQGbbTR5yGS3mSnzlfen',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737e4903912ce70058bcd0f501',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027e4903912ce70058bcd0f501',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517e4903912ce70058bcd0f501',
#        'width': 64}],
#      'name': 'Filmscore Excursions',
#      'release_date': '2008-11-02',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:3uIQGbbTR5yGS3mSnzlfen'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Z4uvjnOZVHec4E4gbWolx'},
#       'href': 'https://api.spotify.com/v1/artists/6Z4uvjnOZVHec4E4gbWolx',
#       'id': '6Z4uvjnOZVHec4E4gbWolx',
#       'name': 'Udi Harpaz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Z4uvjnOZVHec4E4gbWolx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 146093,
#     'explicit': False,
#     'external_ids': {'isrc': 'US1ST1401863'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ATuBhVdGfH1w2sdFaM42E'},
#     'href': 'https://api.spotify.com/v1/tracks/0ATuBhVdGfH1w2sdFaM42E',
#     'id': '0ATuBhVdGfH1w2sdFaM42E',
#     'is_local': False,
#     'name': 'Penguins March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cd056ed54117d11565663492b0b1669b8f710876?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:0ATuBhVdGfH1w2sdFaM42E'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7FE7rH0UfJwX8ZX1wWNRoJ'},
#        'href': 'https://api.spotify.com/v1/artists/7FE7rH0UfJwX8ZX1wWNRoJ',
#        'id': '7FE7rH0UfJwX8ZX1wWNRoJ',
#        'name': 'Tetsuro Ichii',
#        'type': 'artist',
#        'uri': 'spotify:artist:7FE7rH0UfJwX8ZX1wWNRoJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XbOg1ImTQ3P8WmLe725Ms'},
#      'href': 'https://api.spotify.com/v1/albums/4XbOg1ImTQ3P8WmLe725Ms',
#      'id': '4XbOg1ImTQ3P8WmLe725Ms',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733be9eb2e4510f9754ddd15af',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023be9eb2e4510f9754ddd15af',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513be9eb2e4510f9754ddd15af',
#        'width': 64}],
#      'name': 'Eternal Birth',
#      'release_date': '2018-05-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4XbOg1ImTQ3P8WmLe725Ms'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O1mntSFn7fax54Sbiz6mF'},
#       'href': 'https://api.spotify.com/v1/artists/4O1mntSFn7fax54Sbiz6mF',
#       'id': '4O1mntSFn7fax54Sbiz6mF',
#       'name': 'Ichii Tetsuro',
#       'type': 'artist',
#       'uri': 'spotify:artist:4O1mntSFn7fax54Sbiz6mF'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 97359,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCJPH1807598'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/33KMEmLfcvfWd1IaRI9Qzn'},
#     'href': 'https://api.spotify.com/v1/tracks/33KMEmLfcvfWd1IaRI9Qzn',
#     'id': '33KMEmLfcvfWd1IaRI9Qzn',
#     'is_local': False,
#     'name': 'Penguin March',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8be052e3eecce4e82603656495258f74254246a5?cid=1544e44f656f402894c4b6b4c0efdf9b',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:33KMEmLfcvfWd1IaRI9Qzn'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Penguin+March&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 66}}

# %%
track_id='5enoGqbp3D0cZfzlx5EtUU'
rel_artists = sp.artist_related_artists(sp.track(track_id=track_id)['artists'][0]['id'])['artists']
artist_log = []
for a in rel_artists:
    artist_log.append(a['id'])
    feat_log = []
for artist in artist_log:
    for track in sp.artist_top_tracks(artist)['tracks']:
        feat_log.append(sp.audio_features(track['id'])[0])
        
        catalog = pd.DataFrame.from_dict(feat_log)
    
        root = pd.DataFrame.from_dict(sp.audio_features(tracks=[track_id]))

        merged_df = root.append(catalog, ignore_index=True)
    
        dropped_df = merged_df.drop(columns=['uri', 'track_href', 'id', 'duration_ms', 'time_signature', 'mode', 'loudness', 'type', 'analysis_url'])

# %%
dropped_df.shape
# Out:
# (116, 9)

# %%
dropped_df.head()
# Out:
#    danceability  energy  key  speechiness  acousticness  instrumentalness  \
# 0         0.256   0.283    2       0.0380        0.7130             0.969
# 1         0.686   0.989    5       0.3030        0.0832             0.161
# 2         0.822   0.890    0       0.0914        0.0111             0.263
# 3         0.711   0.999    8       0.0983        0.0817             0.814
# 4         0.666   0.885   11       0.0693        0.0117             0.930
#
#    liveness  valence    tempo
# 0    0.1230   0.0642   86.438
# 1    0.8900   0.2110  141.564
# 2    0.0532   0.0992   85.976
# 3    0.0861   0.2180   91.966
# 4    0.2610   0.6520   86.972

# %%
def dj_rec(track_id, max_distance=6.5, neighbors=3):
    """
    Prints the ids of relevant songs, along with their distance from the input song.

    Parameters:
    track_id (string): Spotify track id.
    max_distance (float): maximum euclidean distance a song can be 
                          from the input song for it to be returned.
    neighbors (int): number of song recommendations returned.
    """

    rel_artists = sp.artist_related_artists(sp.track(track_id=track_id)['artists'][0]['id'])['artists']
    artist_log = []
    for a in rel_artists:
        artist_log.append(a['id'])
    feat_log = []
    for artist in artist_log:
        for track in sp.artist_top_tracks(artist)['tracks']:
            feat_log.append(sp.audio_features(track['id'])[0])
    
    catalog = pd.DataFrame.from_dict(feat_log)
    
    root = pd.DataFrame.from_dict(sp.audio_features(tracks=[track_id]))

    merged_df = root.append(catalog, ignore_index=True)
    
    dropped_df = merged_df.drop(columns=['uri', 'track_href', 'id', 'duration_ms', 'time_signature', 'mode', 'loudness', 'type', 'analysis_url'])
    scaled_df = StandardScaler().fit_transform(dropped_df)
    trans_array = scaled_df.copy()
    trans_array[:,0] = [u*2.4 for u in trans_array[:,0]] # acousticness
    trans_array[:,1] = [((u*u)**0.5)*u for u in trans_array[:,1]] # danceability
    trans_array[:,2] = [u*1.7 for u in trans_array[:,2]] # energy
    trans_array[:,3] = [u*1.4 for u in trans_array[:,3]] # instrumentalness
    trans_array[:,4] = [u*0.9 for u in trans_array[:,4]] # key
    trans_array[:,5] = [u*1.0 for u in trans_array[:,5]] # liveness
    trans_array[:,6] = [u*1.0 for u in trans_array[:,6]] # speechiness
    trans_array[:,7] = [u*1.1 for u in trans_array[:,7]] # tempo
    trans_array[:,8] = [u*2.5 for u in trans_array[:,8]] # valence

    knn = NearestNeighbors()
    knn.fit(trans_array)

    rec = knn.kneighbors(trans_array[[0]], n_neighbors=neighbors+1)

    print('Seed')
    print('ID:     ', root.loc[0,'id'], '\n')
    print('\nRecommendations')

    for n in range(1,neighbors+1):
        if rec[0][0][n] <= max_distance:
            print('ID:      ', merged_df.loc[rec[1][0][n],'id'])
            print('Distance:', rec[0][0][n], '\n')
            print('\n')
            
    if rec[0][0][1] > max_distance:
        print('No matches in catalog')

# %%
# Example

dj_rec(song_id, max_distance=6.5, neighbors=3)
# Out:
# Seed
# ID:      0gjfdXCV6yrwhP23NVx1Fm
#
#
# Recommendations
# ID:       0RVIcy8jrmjM9yYfm3HHF4
# Distance: 3.3693379690497864
#
#
#
# ID:       3eoXrssdwFYhOlzsJ8sssE
# Distance: 4.542219136496946
#
#
#
# ID:       5iTnzXYuEmaJ1ioJ95JC99
# Distance: 4.590865009363061

# %%
rec_id = '0RVIcy8jrmjM9yYfm3HHF4'

# %%
print(sp.track(song_id)['artists'][0]['name']+ ' - ' 
      + sp.track(song_id)['name']+ ' - ' 
      + sp.track(song_id)['external_urls']['spotify'])
# Out:
# Nite Fleit - Reply All - https://open.spotify.com/track/0gjfdXCV6yrwhP23NVx1Fm

# %%
print(sp.track(rec_id)['artists'][0]['name']+ ' - ' 
      + sp.track(rec_id)['name']+ ' - ' 
      + sp.track(rec_id)['external_urls']['spotify'])
# Out:
# Special Request - Arse End of the Moon - https://open.spotify.com/track/0RVIcy8jrmjM9yYfm3HHF4

# %%
sp.track(song_id)['artists'][0]['name']
# Out:
# 'Nite Fleit'

# %%
sp.track(song_id)['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yVtpTbLBVQ2FykO9CETC5'},
#   'href': 'https://api.spotify.com/v1/artists/1yVtpTbLBVQ2FykO9CETC5',
#   'id': '1yVtpTbLBVQ2FykO9CETC5',
#   'name': 'Nite Fleit',
#   'type': 'artist',
#   'uri': 'spotify:artist:1yVtpTbLBVQ2FykO9CETC5'}]

# %%
sp.track(song_id)['name']
# Out:
# 'Reply All'
