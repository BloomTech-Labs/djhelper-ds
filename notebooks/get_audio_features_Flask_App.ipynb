# %% [markdown]
# ## Create a token to use for Spotify queries

# %% [markdown]
# ### Load Libraries

# %%
import spotipy
import spotipy.util as util
import sys
import requests
from dotenv import load_dotenv
import os

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import pandas as pd
import json

# %%
from flask import jsonify

# %%
load_dotenv() # load environment variables
# Out:
# True

# %%
client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# ### Load Spotify variables

# %%
SEARCH_ENDPOINT = 'https://api.spotify.com/v1/search'
CLIENT_ID = os.getenv('SPOTIPY_CLIENT_ID', default="OOPS")
CLIENT_SECRET = os.getenv('SPOTIPY_CLIENT_SECRET', default="OOPS")

# %% [markdown]
# ### Load client credentials to create a token

# %%
data = {'grant_type': 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'
response = requests.post(url, data=data, auth=(CLIENT_ID, CLIENT_SECRET))
token = response.json()['access_token']

# %% [markdown]
# #### You can print it out to check if code works

# %%
# print(token)
# print(response.json()['access_token'])

# %% [markdown]
# ### Check how token performs

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer {}'.format(token)
}

# %%
params = (
        ('type', 'track'),
        ('limit', 5)
)

# %% [markdown]
# ### One way of implementing the search function

# %%
song_track = 'the unknown' # song name, choose any

# %%
song = requests.get("https://api.spotify.com/v1/search?q="+ song_track + "&type=track",
                   headers=headers, params=params)

# %% [markdown]
# ### Other way of doing it

# %%
name = song_track

# %%
myparams = {'type': 'track', 'limit': 10}
myparams['q'] = name
resp = requests.get(SEARCH_ENDPOINT, headers=headers, params=myparams)

# %% [markdown]
# ### Check for response '200'

# %%
song
# Out:
# <Response [200]>

# %%
resp
# Out:
# <Response [200]>

# %% [markdown]
# ### You have plenty of features to choose from

# %%
print(song.json())
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=0&limit=5', 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph'}, 'href': 'https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph', 'id': '0REMf7H0VP6DwfZ9MbuWph', 'name': '10 Years', 'type': 'artist', 'uri': 'spotify:artist:0REMf7H0VP6DwfZ9MbuWph'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0qFOyJ2NsyTjgWXYGPAZxM'}, 'href': 'https://api.spotify.com/v1/albums/0qFOyJ2NsyTjgWXYGPAZxM', 'id': '0qFOyJ2NsyTjgWXYGPAZxM', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27342cbef66db5480fc654a327b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485142cbef66db5480fc654a327b', 'width': 64}], 'name': 'The Unknown', 'release_date': '2020-07-10', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:0qFOyJ2NsyTjgWXYGPAZxM'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph'}, 'href': 'https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph', 'id': '0REMf7H0VP6DwfZ9MbuWph', 'name': '10 Years', 'type': 'artist', 'uri': 'spotify:artist:0REMf7H0VP6DwfZ9MbuWph'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 180592, 'explicit': False, 'external_ids': {'isrc': 'NLB932001702'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2'}, 'href': 'https://api.spotify.com/v1/tracks/0gxBrbuodVvvHyXtpXOun2', 'id': '0gxBrbuodVvvHyXtpXOun2', 'is_local': False, 'name': 'The Unknown', 'popularity': 50, 'preview_url': 'https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:0gxBrbuodVvvHyXtpXOun2'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US ...

# %%
print(resp.text)
# Out:
# {
#   "tracks" : {
#     "href" : "https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=0&limit=10",
#     "items" : [ {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph",
#           "id" : "0REMf7H0VP6DwfZ9MbuWph",
#           "name" : "10 Years",
#           "type" : "artist",
#           "uri" : "spotify:artist:0REMf7H0VP6DwfZ9MbuWph"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0qFOyJ2NsyTjgWXYGPAZxM"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0qFOyJ2NsyTjgWXYGPAZxM",
#         "id" : "0qFOyJ2NsyTjgWXYGPAZxM",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b27342cbef66db5480fc654a327b",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d0000485142cbef66db5480fc654a327b",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2020-07-10",
#         "release_date_precision" : "day",
#         "total_tracks" : 2,
#         "type" : "album",
#         "uri" : "spotify:album:0qFOyJ2NsyTjgWXYGPAZxM"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph"
#         },
#         "href" : "https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph",
#         "id" : "0REMf7H0VP6DwfZ9MbuWph",
#         "name" : "10 Years",
#         "type" : "artist",
#         "uri" : "spotify:artist:0REMf7H0VP6DwfZ9MbuWph"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 180592,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "NLB932001702"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/0gxBrbuodVvvHyXtpXOun2",
#       "id" : "0gxBrbuodVvvHyXtpXOun2",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 50,
#       "preview_url" : "https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:0gxBrbuodVvvHyXtpXOun2"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#           "id" : "0LyfQWJT6nXafLPZqxe9Of",
#           "name" : "Various Artists",
#           "type" : "artist",
#           "uri" : "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/4M07HWIlZr7zoXoxDHR5mz"
#         },
#         "href" : "https://api.spotify.com/v1/albums/4M07HWIlZr7zoXoxDHR5mz",
#         "id" : "4M07HWIlZr7zoXoxDHR5mz",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736ff59d18c018a2845758deed",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516ff59d18c018a2845758deed",
#           "width" : 64
#         } ],
#         "name" : "Frozen 2 (Original Motion Picture Soundtrack/Deluxe Edition)",
#         "release_date" : "2019-11-15",
#         "release_date_precision" : "day",
#         "total_tracks" : 46,
#         "type" : "album",
#         "uri" : "spotify:album:4M07HWIlZr7zoXoxDHR5mz"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/73Np75Wv2tju61Eo9Zw4IR"
#         },
#         "href" : "https://api.spotify.com/v1/artists/73Np75Wv2tju61Eo9Zw4IR",
#         "id" : "73Np75Wv2tju61Eo9Zw4IR",
#         "name" : "Idina Menzel",
#         "type" : "artist",
#         "uri" : "spotify:artist:73Np75Wv2tju61Eo9Zw4IR"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N",
#         "id" : "1WgXqy2Dd70QQOU7Ay074N",
#         "name" : "AURORA",
#         "type" : "artist",
#         "uri" : "spotify:artist:1WgXqy2Dd70QQOU7Ay074N"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 194848,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USWD11994667"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3Z0oQ8r78OUaHvGPiDBR3W"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3Z0oQ8r78OUaHvGPiDBR3W",
#       "id" : "3Z0oQ8r78OUaHvGPiDBR3W",
#       "is_local" : false,
#       "name" : "Into the Unknown",
#       "popularity" : 79,
#       "preview_url" : null,
#       "track_number" : 3,
#       "type" : "track",
#       "uri" : "spotify:track:3Z0oQ8r78OUaHvGPiDBR3W"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/4IR8ZkpbyyKrqsIzchF3NB"
#           },
#           "href" : "https://api.spotify.com/v1/artists/4IR8ZkpbyyKrqsIzchF3NB",
#           "id" : "4IR8ZkpbyyKrqsIzchF3NB",
#           "name" : "Crossfade",
#           "type" : "artist",
#           "uri" : "spotify:artist:4IR8ZkpbyyKrqsIzchF3NB"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/1namjaJZ23ozXXB7X2d4hy"
#         },
#         "href" : "https://api.spotify.com/v1/albums/1namjaJZ23ozXXB7X2d4hy",
#         "id" : "1namjaJZ23ozXXB7X2d4hy",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736655dcd1e8b57d0022f856e6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026655dcd1e8b57d0022f856e6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516655dcd1e8b57d0022f856e6",
#           "width" : 64
#         } ],
#         "name" : "Crossfade",
#         "release_date" : "2004-04-13",
#         "release_date_precision" : "day",
#         "total_tracks" : 10,
#         "type" : "album",
#         "uri" : "spotify:album:1namjaJZ23ozXXB7X2d4hy"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/4IR8ZkpbyyKrqsIzchF3NB"
#         },
#         "href" : "https://api.spotify.com/v1/artists/4IR8ZkpbyyKrqsIzchF3NB",
#         "id" : "4IR8ZkpbyyKrqsIzchF3NB",
#         "name" : "Crossfade",
#         "type" : "artist",
#         "uri" : "spotify:artist:4IR8ZkpbyyKrqsIzchF3NB"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 179120,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USSM10400177"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/7Eg9qnJK7hI7LLoRsbvH2X"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/7Eg9qnJK7hI7LLoRsbvH2X",
#       "id" : "7Eg9qnJK7hI7LLoRsbvH2X",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 46,
#       "preview_url" : "https://p.scdn.co/mp3-preview/0f95c28210930bcb4cbd7100d122c24412d42c87?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 10,
#       "type" : "track",
#       "uri" : "spotify:track:7Eg9qnJK7hI7LLoRsbvH2X"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q"
#           },
#           "href" : "https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q",
#           "id" : "53XhwfbYqKCa1cC15pYq2q",
#           "name" : "Imagine Dragons",
#           "type" : "artist",
#           "uri" : "spotify:artist:53XhwfbYqKCa1cC15pYq2q"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HN", "HR", "HU", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SI", "SK", "SV", "TN", "TR", "UA", "US", "UY", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6ecx4OFG0nlUMqAi9OXQER"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6ecx4OFG0nlUMqAi9OXQER",
#         "id" : "6ecx4OFG0nlUMqAi9OXQER",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2731551c93dfa33ea4f30ef4eea",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048511551c93dfa33ea4f30ef4eea",
#           "width" : 64
#         } ],
#         "name" : "Smoke + Mirrors (Deluxe)",
#         "release_date" : "2015-10-30",
#         "release_date_precision" : "day",
#         "total_tracks" : 21,
#         "type" : "album",
#         "uri" : "spotify:album:6ecx4OFG0nlUMqAi9OXQER"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q"
#         },
#         "href" : "https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q",
#         "id" : "53XhwfbYqKCa1cC15pYq2q",
#         "name" : "Imagine Dragons",
#         "type" : "artist",
#         "uri" : "spotify:artist:53XhwfbYqKCa1cC15pYq2q"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HN", "HR", "HU", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SI", "SK", "SV", "TN", "TR", "UA", "US", "UY", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 204720,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USUM71417940"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/4DRQBzgiM3SQqO5bXXPGpb"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/4DRQBzgiM3SQqO5bXXPGpb",
#       "id" : "4DRQBzgiM3SQqO5bXXPGpb",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 45,
#       "preview_url" : null,
#       "track_number" : 15,
#       "type" : "track",
#       "uri" : "spotify:track:4DRQBzgiM3SQqO5bXXPGpb"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/74xeHqz5Ap8ZHq69TkxI0r"
#           },
#           "href" : "https://api.spotify.com/v1/artists/74xeHqz5Ap8ZHq69TkxI0r",
#           "id" : "74xeHqz5Ap8ZHq69TkxI0r",
#           "name" : "BONNIE X CLYDE",
#           "type" : "artist",
#           "uri" : "spotify:artist:74xeHqz5Ap8ZHq69TkxI0r"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6akNhXVhvX9OySiINEyXCF"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6akNhXVhvX9OySiINEyXCF",
#         "id" : "6akNhXVhvX9OySiINEyXCF",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b273606ad337bb83dc55c3698b36",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e02606ad337bb83dc55c3698b36",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d00004851606ad337bb83dc55c3698b36",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2018-05-11",
#         "release_date_precision" : "day",
#         "total_tracks" : 1,
#         "type" : "album",
#         "uri" : "spotify:album:6akNhXVhvX9OySiINEyXCF"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/74xeHqz5Ap8ZHq69TkxI0r"
#         },
#         "href" : "https://api.spotify.com/v1/artists/74xeHqz5Ap8ZHq69TkxI0r",
#         "id" : "74xeHqz5Ap8ZHq69TkxI0r",
#         "name" : "BONNIE X CLYDE",
#         "type" : "artist",
#         "uri" : "spotify:artist:74xeHqz5Ap8ZHq69TkxI0r"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 173538,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "TCADP1871048"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3j5udcJCWrQK51O6wahLyf"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3j5udcJCWrQK51O6wahLyf",
#       "id" : "3j5udcJCWrQK51O6wahLyf",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 45,
#       "preview_url" : "https://p.scdn.co/mp3-preview/81ce4a86d980c7e5e5d9ac1cd8302ebf938aa481?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:3j5udcJCWrQK51O6wahLyf"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/7ur5xQmbRVw7992qVyfjRM"
#           },
#           "href" : "https://api.spotify.com/v1/artists/7ur5xQmbRVw7992qVyfjRM",
#           "id" : "7ur5xQmbRVw7992qVyfjRM",
#           "name" : "Twoxxtremes",
#           "type" : "artist",
#           "uri" : "spotify:artist:7ur5xQmbRVw7992qVyfjRM"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6UXFTAmyGkpZbyZpiOFjBt"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6UXFTAmyGkpZbyZpiOFjBt",
#         "id" : "6UXFTAmyGkpZbyZpiOFjBt",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2734121c143b34ebfb5936689e6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e024121c143b34ebfb5936689e6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048514121c143b34ebfb5936689e6",
#           "width" : 64
#         } ],
#         "name" : "X.X.",
#         "release_date" : "2019-08-05",
#         "release_date_precision" : "day",
#         "total_tracks" : 5,
#         "type" : "album",
#         "uri" : "spotify:album:6UXFTAmyGkpZbyZpiOFjBt"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/7ur5xQmbRVw7992qVyfjRM"
#         },
#         "href" : "https://api.spotify.com/v1/artists/7ur5xQmbRVw7992qVyfjRM",
#         "id" : "7ur5xQmbRVw7992qVyfjRM",
#         "name" : "Twoxxtremes",
#         "type" : "artist",
#         "uri" : "spotify:artist:7ur5xQmbRVw7992qVyfjRM"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 69197,
#       "explicit" : true,
#       "external_ids" : {
#         "isrc" : "QZFZ61914748"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3TQerxyGsmsmGaWb0J7uhg"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3TQerxyGsmsmGaWb0J7uhg",
#       "id" : "3TQerxyGsmsmGaWb0J7uhg",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 38,
#       "preview_url" : "https://p.scdn.co/mp3-preview/0c2ef5df7ae756805ac3c17750f5600a3e943a67?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 5,
#       "type" : "track",
#       "uri" : "spotify:track:3TQerxyGsmsmGaWb0J7uhg"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#           "id" : "0LyfQWJT6nXafLPZqxe9Of",
#           "name" : "Various Artists",
#           "type" : "artist",
#           "uri" : "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/4M07HWIlZr7zoXoxDHR5mz"
#         },
#         "href" : "https://api.spotify.com/v1/albums/4M07HWIlZr7zoXoxDHR5mz",
#         "id" : "4M07HWIlZr7zoXoxDHR5mz",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736ff59d18c018a2845758deed",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516ff59d18c018a2845758deed",
#           "width" : 64
#         } ],
#         "name" : "Frozen 2 (Original Motion Picture Soundtrack/Deluxe Edition)",
#         "release_date" : "2019-11-15",
#         "release_date_precision" : "day",
#         "total_tracks" : 46,
#         "type" : "album",
#         "uri" : "spotify:album:4M07HWIlZr7zoXoxDHR5mz"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/20JZFwl6HVl6yg8a4H3ZqK"
#         },
#         "href" : "https://api.spotify.com/v1/artists/20JZFwl6HVl6yg8a4H3ZqK",
#         "id" : "20JZFwl6HVl6yg8a4H3ZqK",
#         "name" : "Panic! At The Disco",
#         "type" : "artist",
#         "uri" : "spotify:artist:20JZFwl6HVl6yg8a4H3ZqK"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 189132,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USWD11994800"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/421eObjg0DTm2qajJl5OJm"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/421eObjg0DTm2qajJl5OJm",
#       "id" : "421eObjg0DTm2qajJl5OJm",
#       "is_local" : false,
#       "name" : "Into the Unknown - Panic! At The Disco Version",
#       "popularity" : 75,
#       "preview_url" : null,
#       "track_number" : 9,
#       "type" : "track",
#       "uri" : "spotify:track:421eObjg0DTm2qajJl5OJm"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt"
#           },
#           "href" : "https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt",
#           "id" : "22WZ7M8sxp5THdruNY3gXt",
#           "name" : "The Doors",
#           "type" : "artist",
#           "uri" : "spotify:artist:22WZ7M8sxp5THdruNY3gXt"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0qZTwrunzX3LG45PvRghmh"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0qZTwrunzX3LG45PvRghmh",
#         "id" : "0qZTwrunzX3LG45PvRghmh",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2733f695bca9b4a89457e42ce22",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e023f695bca9b4a89457e42ce22",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048513f695bca9b4a89457e42ce22",
#           "width" : 64
#         } ],
#         "name" : "Waiting for the Sun",
#         "release_date" : "1968-07-03",
#         "release_date_precision" : "day",
#         "total_tracks" : 11,
#         "type" : "album",
#         "uri" : "spotify:album:0qZTwrunzX3LG45PvRghmh"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt"
#         },
#         "href" : "https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt",
#         "id" : "22WZ7M8sxp5THdruNY3gXt",
#         "name" : "The Doors",
#         "type" : "artist",
#         "uri" : "spotify:artist:22WZ7M8sxp5THdruNY3gXt"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 201106,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USEE19900749"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/78JYtz4yOPqAEgZZc3SBLT"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/78JYtz4yOPqAEgZZc3SBLT",
#       "id" : "78JYtz4yOPqAEgZZc3SBLT",
#       "is_local" : false,
#       "name" : "The Unknown Soldier",
#       "popularity" : 49,
#       "preview_url" : "https://p.scdn.co/mp3-preview/c2771fe651f4c1b4906df856e354cb7f7071fbd2?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 6,
#       "type" : "track",
#       "uri" : "spotify:track:78JYtz4yOPqAEgZZc3SBLT"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18"
#           },
#           "href" : "https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18",
#           "id" : "7ItbAZITSFxSy5LJChXe18",
#           "name" : "ford.",
#           "type" : "artist",
#           "uri" : "spotify:artist:7ItbAZITSFxSy5LJChXe18"
#         }, {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/1eL4DVwObeAZjGOVjASAXd"
#           },
#           "href" : "https://api.spotify.com/v1/artists/1eL4DVwObeAZjGOVjASAXd",
#           "id" : "1eL4DVwObeAZjGOVjASAXd",
#           "name" : "Hanz",
#           "type" : "artist",
#           "uri" : "spotify:artist:1eL4DVwObeAZjGOVjASAXd"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0Mly9ByCUByZRYCLZkEtqf"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0Mly9ByCUByZRYCLZkEtqf",
#         "id" : "0Mly9ByCUByZRYCLZkEtqf",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b273d61aa27a9efeb0049d1f77b6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e02d61aa27a9efeb0049d1f77b6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d00004851d61aa27a9efeb0049d1f77b6",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2018-03-16",
#         "release_date_precision" : "day",
#         "total_tracks" : 1,
#         "type" : "album",
#         "uri" : "spotify:album:0Mly9ByCUByZRYCLZkEtqf"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18"
#         },
#         "href" : "https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18",
#         "id" : "7ItbAZITSFxSy5LJChXe18",
#         "name" : "ford.",
#         "type" : "artist",
#         "uri" : "spotify:artist:7ItbAZITSFxSy5LJChXe18"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1eL4DVwObeAZjGOVjASAXd"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1eL4DVwObeAZjGOVjASAXd",
#         "id" : "1eL4DVwObeAZjGOVjASAXd",
#         "name" : "Hanz",
#         "type" : "artist",
#         "uri" : "spotify:artist:1eL4DVwObeAZjGOVjASAXd"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/5aNJpeK3hUdPY9orfExdOF"
#         },
#         "href" : "https://api.spotify.com/v1/artists/5aNJpeK3hUdPY9orfExdOF",
#         "id" : "5aNJpeK3hUdPY9orfExdOF",
#         "name" : "Ayelle",
#         "type" : "artist",
#         "uri" : "spotify:artist:5aNJpeK3hUdPY9orfExdOF"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 211596,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "TCADN1813258"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/4FXHLmzOMGLy5jFj6ctDsn"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/4FXHLmzOMGLy5jFj6ctDsn",
#       "id" : "4FXHLmzOMGLy5jFj6ctDsn",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 42,
#       "preview_url" : "https://p.scdn.co/mp3-preview/d8fd578f56458c000954181fcff4c5624f83a988?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:4FXHLmzOMGLy5jFj6ctDsn"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/3eCd0TZrBPm2n9cDG6yWfF"
#           },
#           "href" : "https://api.spotify.com/v1/artists/3eCd0TZrBPm2n9cDG6yWfF",
#           "id" : "3eCd0TZrBPm2n9cDG6yWfF",
#           "name" : "DEAN",
#           "type" : "artist",
#           "uri" : "spotify:artist:3eCd0TZrBPm2n9cDG6yWfF"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/48ScAfcD1Dy3gMPhjhTzek"
#         },
#         "href" : "https://api.spotify.com/v1/albums/48ScAfcD1Dy3gMPhjhTzek",
#         "id" : "48ScAfcD1Dy3gMPhjhTzek",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2739a4616cc6ce6c1aa0c265d8d",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e029a4616cc6ce6c1aa0c265d8d",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048519a4616cc6ce6c1aa0c265d8d",
#           "width" : 64
#         } ],
#         "name" : "Limbo",
#         "release_date" : "2017-02-17",
#         "release_date_precision" : "day",
#         "total_tracks" : 2,
#         "type" : "album",
#         "uri" : "spotify:album:48ScAfcD1Dy3gMPhjhTzek"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3eCd0TZrBPm2n9cDG6yWfF"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3eCd0TZrBPm2n9cDG6yWfF",
#         "id" : "3eCd0TZrBPm2n9cDG6yWfF",
#         "name" : "DEAN",
#         "type" : "artist",
#         "uri" : "spotify:artist:3eCd0TZrBPm2n9cDG6yWfF"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 116758,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "KRUM71700060"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/28WctYFXTOeQm4FTYgENyp"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/28WctYFXTOeQm4FTYgENyp",
#       "id" : "28WctYFXTOeQm4FTYgENyp",
#       "is_local" : false,
#       "name" : "The Unknown Guest",
#       "popularity" : 45,
#       "preview_url" : null,
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:28WctYFXTOeQm4FTYgENyp"
#     } ],
#     "limit" : 10,
#     "next" : "https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=10&limit=10",
#     "offset" : 0,
#     "previous" : null,
#     "total" : 29583
#   }
# }

# %% [markdown]
# ### You can enumerate through them

# %%
res = resp.json() # transform the 200 result in to json file first

# %%
for i, track in enumerate(res['tracks']['items']):
    print(' ', i, track['name'],'-', track['artists'][0]['name'], '-', track['id'],
         '-', track['external_urls']['spotify'], '-', track['explicit'],
         track['preview_url'], track['album']['images'][1]['url'])
# Out:
#   0 The Unknown - 10 Years - 0gxBrbuodVvvHyXtpXOun2 - https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2 - False https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b
#   1 Into the Unknown - Idina Menzel - 3Z0oQ8r78OUaHvGPiDBR3W - https://open.spotify.com/track/3Z0oQ8r78OUaHvGPiDBR3W - False None https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed
#   2 The Unknown - Crossfade - 7Eg9qnJK7hI7LLoRsbvH2X - https://open.spotify.com/track/7Eg9qnJK7hI7LLoRsbvH2X - False https://p.scdn.co/mp3-preview/0f95c28210930bcb4cbd7100d122c24412d42c87?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e026655dcd1e8b57d0022f856e6
#   3 The Unknown - Imagine Dragons - 4DRQBzgiM3SQqO5bXXPGpb - https://open.spotify.com/track/4DRQBzgiM3SQqO5bXXPGpb - False None https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea
#   4 The Unknown - BONNIE X CLYDE - 3j5udcJCWrQK51O6wahLyf - https://open.spotify.com/track/3j5udcJCWrQK51O6wahLyf - False https://p.scdn.co/mp3-preview/81ce4a86d980c7e5e5d9ac1cd8302ebf938aa481?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e02606ad337bb83dc55c3698b36
#   5 The Unknown - Twoxxtremes - 3TQerxyGsmsmGaWb0J7uhg - https://open.spotify.com/track/3TQerxyGsmsmGaWb0J7uhg - True https://p.scdn.co/mp3-preview/0c2ef5df7ae756805ac3c17750f5600a3e943a67?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e024121c143b34ebfb5936689e6
#   6 Into the Unknown - Panic! At The Disco Version - Panic! At The Disco - 421eObjg0DTm2qajJl5OJm - https://open.spotify.com/track/421eObjg0DTm2qajJl5OJm - False None https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed
#   7 The Unknown Soldier - The Doors - 78JYtz4yOPqAEgZZc3SBLT - https://open.spotify.com/track/78JYtz4yOPqAEgZZc3SBLT - False https://p.scdn.co/mp3-preview/c2771fe651f4c1b4906df856e354cb7f7071fbd2?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e023f695bca9b4a89457e42ce22
#   8 The Unknown - ford. - 4FXHLmzOMGLy5jFj6ctDsn - https://open.spotify.com/track/4FXHLmzOMGLy5jFj6ctDsn - False https://p.scdn.co/mp3-preview/d8fd578f56458c000954181fcff4c5624f83a988?cid=1544e44f656f402894c4b6b4c0efdf9b https://i.scdn.co/image/ab67616d00001e02d61aa27a9efeb0049d1f77b6
#   9 The Unknown Guest - DEAN - 28WctYFXTOeQm4FTYgENyp - https://open.spotify.com/track/28WctYFXTOeQm4FTYgENyp - False None https://i.scdn.co/image/ab67616d00001e029a4616cc6ce6c1aa0c265d8d

# %% [markdown]
# ### You can look for 'artist' instead of a 'song'

# %%
ide = 'madonna'

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer {}'.format(token)
}

# %%
params = (
        ('type', 'track'),
        ('limit', 5)
    )

# %%
art = requests.get("https://api.spotify.com/v1/search?q="+ ide + "&type=track", headers=headers, params=params)

# %%
art
# Out:
# <Response [200]>

# %%
# print(art.json())

# %% [markdown]
# ## Prepare merge function for FLASK App

# %% [markdown]
# ### Get audio features for the search result

# %%
users_response = []
for i, track in enumerate(res['tracks']['items']):
    user_dict = (i, track['artists'][0]['name'], track['name'], track['id'], track['external_urls']['spotify'],
                 track['explicit'], track['preview_url'], track['album']['images'][1]['url'])
    users_response.append(user_dict)

# %%
_track_df = pd.DataFrame(users_response, columns = ['ind','artist_name', 'song_name', 
                                                    'id', 'external_urls', 'explicit', 'preview',
                                                   'image'])

# %%
_track_df = _track_df.drop(['ind'], axis=1)

# %%
_track_df.head()
# Out:
#        artist_name         song_name                      id  \
# 0         10 Years       The Unknown  0gxBrbuodVvvHyXtpXOun2
# 1     Idina Menzel  Into the Unknown  3Z0oQ8r78OUaHvGPiDBR3W
# 2        Crossfade       The Unknown  7Eg9qnJK7hI7LLoRsbvH2X
# 3  Imagine Dragons       The Unknown  4DRQBzgiM3SQqO5bXXPGpb
# 4   BONNIE X CLYDE       The Unknown  3j5udcJCWrQK51O6wahLyf
#
#                                        external_urls  explicit  \
# 0  https://open.spotify.com/track/0gxBrbuodVvvHyX...     False
# 1  https://open.spotify.com/track/3Z0oQ8r78OUaHvG...     False
# 2  https://open.spotify.com/track/7Eg9qnJK7hI7LLo...     False
# 3  https://open.spotify.com/track/4DRQBzgiM3SQqO5...     False
# 4  https://open.spotify.com/track/3j5udcJCWrQK51O...     False
#
#                                              preview  \
# 0  https://p.scdn.co/mp3-preview/ee2b37855716c77f...
# 1                                               None
# 2  https://p.scdn.co/mp3-preview/0f95c28210930bcb...
# 3                                               None
# 4  https://p.scdn.co/mp3-preview/81ce4a86d980c7e5...
#
#                                                image
# 0  https://i.scdn.co/image/ab67616d00001e0242cbef...
# 1  https://i.scdn.co/image/ab67616d00001e026ff59d...
# 2  https://i.scdn.co/image/ab67616d00001e026655dc...
# 3  https://i.scdn.co/image/ab67616d00001e021551c9...
# 4  https://i.scdn.co/image/ab67616d00001e02606ad3...

# %%
# Check for None values
_track_df['preview'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: preview, dtype: bool

# %%
# Replace the None values with the URL desired
def get_rid_of_nulls(value):
    if pd.isnull(value):
        return 'http://bit.ly/2nXRRfX'
    else:
        return value

# %%
# Apply the function
_track_df['preview'] = _track_df['preview'].apply(get_rid_of_nulls)

# %%
_track_df.head()
# Out:
#        artist_name         song_name                      id  \
# 0         10 Years       The Unknown  0gxBrbuodVvvHyXtpXOun2
# 1     Idina Menzel  Into the Unknown  3Z0oQ8r78OUaHvGPiDBR3W
# 2        Crossfade       The Unknown  7Eg9qnJK7hI7LLoRsbvH2X
# 3  Imagine Dragons       The Unknown  4DRQBzgiM3SQqO5bXXPGpb
# 4   BONNIE X CLYDE       The Unknown  3j5udcJCWrQK51O6wahLyf
#
#                                        external_urls  explicit  \
# 0  https://open.spotify.com/track/0gxBrbuodVvvHyX...     False
# 1  https://open.spotify.com/track/3Z0oQ8r78OUaHvG...     False
# 2  https://open.spotify.com/track/7Eg9qnJK7hI7LLo...     False
# 3  https://open.spotify.com/track/4DRQBzgiM3SQqO5...     False
# 4  https://open.spotify.com/track/3j5udcJCWrQK51O...     False
#
#                                              preview  \
# 0  https://p.scdn.co/mp3-preview/ee2b37855716c77f...
# 1                              http://bit.ly/2nXRRfX
# 2  https://p.scdn.co/mp3-preview/0f95c28210930bcb...
# 3                              http://bit.ly/2nXRRfX
# 4  https://p.scdn.co/mp3-preview/81ce4a86d980c7e5...
#
#                                                image
# 0  https://i.scdn.co/image/ab67616d00001e0242cbef...
# 1  https://i.scdn.co/image/ab67616d00001e026ff59d...
# 2  https://i.scdn.co/image/ab67616d00001e026655dc...
# 3  https://i.scdn.co/image/ab67616d00001e021551c9...
# 4  https://i.scdn.co/image/ab67616d00001e02606ad3...

# %%
# browse json file
_track_df.to_json(orient="records")
# Out:
# '[{"artist_name":"10 Years","song_name":"The Unknown","id":"0gxBrbuodVvvHyXtpXOun2","external_urls":"https:\\/\\/open.spotify.com\\/track\\/0gxBrbuodVvvHyXtpXOun2","explicit":false,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e0242cbef66db5480fc654a327b"},{"artist_name":"Idina Menzel","song_name":"Into the Unknown","id":"3Z0oQ8r78OUaHvGPiDBR3W","external_urls":"https:\\/\\/open.spotify.com\\/track\\/3Z0oQ8r78OUaHvGPiDBR3W","explicit":false,"preview":"http:\\/\\/bit.ly\\/2nXRRfX","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e026ff59d18c018a2845758deed"},{"artist_name":"Crossfade","song_name":"The Unknown","id":"7Eg9qnJK7hI7LLoRsbvH2X","external_urls":"https:\\/\\/open.spotify.com\\/track\\/7Eg9qnJK7hI7LLoRsbvH2X","explicit":false,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/0f95c28210930bcb4cbd7100d122c24412d42c87?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e026655dcd1e8b57d0022f856e6"},{"artist_name":"Imagine Dragons","song_name":"The Unknown","id":"4DRQBzgiM3SQqO5bXXPGpb","external_urls":"https:\\/\\/open.spotify.com\\/track\\/4DRQBzgiM3SQqO5bXXPGpb","explicit":false,"preview":"http:\\/\\/bit.ly\\/2nXRRfX","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e021551c93dfa33ea4f30ef4eea"},{"artist_name":"BONNIE X CLYDE","song_name":"The Unknown","id":"3j5udcJCWrQK51O6wahLyf","external_urls":"https:\\/\\/open.spotify.com\\/track\\/3j5udcJCWrQK51O6wahLyf","explicit":false,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/81ce4a86d980c7e5e5d9ac1cd8302ebf938aa481?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e02606ad337bb83dc55c3698b36"},{"artist_name":"Twoxxtremes","song_name":"The Unknown","id":"3TQerxyGsmsmGaWb0J7uhg","external_urls":"https:\\/\\/open.spotify.com\\/track\\/3TQerxyGsmsmGaWb0J7uhg","explicit":true,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/0c2ef5df7ae756805ac3c17750f5600a3e943a67?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e024121c143b34ebfb5936689e6"},{"artist_name":"Panic! At The Disco","song_name":"Into the Unknown - Panic! At The Disco Version","id":"421eObjg0DTm2qajJl5OJm","external_urls":"https:\\/\\/open.spotify.com\\/track\\/421eObjg0DTm2qajJl5OJm","explicit":false,"preview":"http:\\/\\/bit.ly\\/2nXRRfX","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e026ff59d18c018a2845758deed"},{"artist_name":"The Doors","song_name":"The Unknown Soldier","id":"78JYtz4yOPqAEgZZc3SBLT","external_urls":"https:\\/\\/open.spotify.com\\/track\\/78JYtz4yOPqAEgZZc3SBLT","explicit":false,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/c2771fe651f4c1b4906df856e354cb7f7071fbd2?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e023f695bca9b4a89457e42ce22"},{"artist_name":"ford.","song_name":"The Unknown","id":"4FXHLmzOMGLy5jFj6ctDsn","external_urls":"https:\\/\\/open.spotify.com\\/track\\/4FXHLmzOMGLy5jFj6ctDsn","explicit":false,"preview":"https:\\/\\/p.scdn.co\\/mp3-preview\\/d8fd578f56458c000954181fcff4c5624f83a988?cid=1544e44f656f402894c4b6b4c0efdf9b","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e02d61aa27a9efeb0049d1f77b6"},{"artist_name":"DEAN","song_name":"The Unknown Guest","id":"28WctYFXTOeQm4FTYgENyp","external_urls":"https:\\/\\/open.spotify.com\\/track\\/28WctYFXTOeQm4FTYgENyp","explicit":false,"preview":"http:\\/\\/bit.ly\\/2nXRRfX","image":"https:\\/\\/i.scdn.co\\/image\\/ab67616d00001e029a4616cc6ce6c1aa0c265d8d"}]'

# %%
# start index from 1
_track_df.index += 1

# %%
_track_df.head(3)
# Out:
#     artist_name         song_name                      id  \
# 1      10 Years       The Unknown  0gxBrbuodVvvHyXtpXOun2
# 2  Idina Menzel  Into the Unknown  3Z0oQ8r78OUaHvGPiDBR3W
# 3     Crossfade       The Unknown  7Eg9qnJK7hI7LLoRsbvH2X
#
#                                        external_urls  explicit  \
# 1  https://open.spotify.com/track/0gxBrbuodVvvHyX...     False
# 2  https://open.spotify.com/track/3Z0oQ8r78OUaHvG...     False
# 3  https://open.spotify.com/track/7Eg9qnJK7hI7LLo...     False
#
#                                              preview  \
# 1  https://p.scdn.co/mp3-preview/ee2b37855716c77f...
# 2                              http://bit.ly/2nXRRfX
# 3  https://p.scdn.co/mp3-preview/0f95c28210930bcb...
#
#                                                image
# 1  https://i.scdn.co/image/ab67616d00001e0242cbef...
# 2  https://i.scdn.co/image/ab67616d00001e026ff59d...
# 3  https://i.scdn.co/image/ab67616d00001e026655dc...

# %% [markdown]
# ### Check the result for later use in Flask App

# %%
print(json.dumps(json.loads(_track_df.to_json(orient='index')), indent=2))
# Out:
# {
#   "1": {
#     "artist_name": "10 Years",
#     "song_name": "The Unknown",
#     "id": "0gxBrbuodVvvHyXtpXOun2",
#     "external_urls": "https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2",
#     "explicit": false,
#     "preview": "https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b"
#   },
#   "2": {
#     "artist_name": "Idina Menzel",
#     "song_name": "Into the Unknown",
#     "id": "3Z0oQ8r78OUaHvGPiDBR3W",
#     "external_urls": "https://open.spotify.com/track/3Z0oQ8r78OUaHvGPiDBR3W",
#     "explicit": false,
#     "preview": "http://bit.ly/2nXRRfX",
#     "image": "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed"
#   },
#   "3": {
#     "artist_name": "Crossfade",
#     "song_name": "The Unknown",
#     "id": "7Eg9qnJK7hI7LLoRsbvH2X",
#     "external_urls": "https://open.spotify.com/track/7Eg9qnJK7hI7LLoRsbvH2X",
#     "explicit": false,
#     "preview": "https://p.scdn.co/mp3-preview/0f95c28210930bcb4cbd7100d122c24412d42c87?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e026655dcd1e8b57d0022f856e6"
#   },
#   "4": {
#     "artist_name": "Imagine Dragons",
#     "song_name": "The Unknown",
#     "id": "4DRQBzgiM3SQqO5bXXPGpb",
#     "external_urls": "https://open.spotify.com/track/4DRQBzgiM3SQqO5bXXPGpb",
#     "explicit": false,
#     "preview": "http://bit.ly/2nXRRfX",
#     "image": "https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea"
#   },
#   "5": {
#     "artist_name": "BONNIE X CLYDE",
#     "song_name": "The Unknown",
#     "id": "3j5udcJCWrQK51O6wahLyf",
#     "external_urls": "https://open.spotify.com/track/3j5udcJCWrQK51O6wahLyf",
#     "explicit": false,
#     "preview": "https://p.scdn.co/mp3-preview/81ce4a86d980c7e5e5d9ac1cd8302ebf938aa481?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e02606ad337bb83dc55c3698b36"
#   },
#   "6": {
#     "artist_name": "Twoxxtremes",
#     "song_name": "The Unknown",
#     "id": "3TQerxyGsmsmGaWb0J7uhg",
#     "external_urls": "https://open.spotify.com/track/3TQerxyGsmsmGaWb0J7uhg",
#     "explicit": true,
#     "preview": "https://p.scdn.co/mp3-preview/0c2ef5df7ae756805ac3c17750f5600a3e943a67?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e024121c143b34ebfb5936689e6"
#   },
#   "7": {
#     "artist_name": "Panic! At The Disco",
#     "song_name": "Into the Unknown - Panic! At The Disco Version",
#     "id": "421eObjg0DTm2qajJl5OJm",
#     "external_urls": "https://open.spotify.com/track/421eObjg0DTm2qajJl5OJm",
#     "explicit": false,
#     "preview": "http://bit.ly/2nXRRfX",
#     "image": "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed"
#   },
#   "8": {
#     "artist_name": "The Doors",
#     "song_name": "The Unknown Soldier",
#     "id": "78JYtz4yOPqAEgZZc3SBLT",
#     "external_urls": "https://open.spotify.com/track/78JYtz4yOPqAEgZZc3SBLT",
#     "explicit": false,
#     "preview": "https://p.scdn.co/mp3-preview/c2771fe651f4c1b4906df856e354cb7f7071fbd2?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e023f695bca9b4a89457e42ce22"
#   },
#   "9": {
#     "artist_name": "ford.",
#     "song_name": "The Unknown",
#     "id": "4FXHLmzOMGLy5jFj6ctDsn",
#     "external_urls": "https://open.spotify.com/track/4FXHLmzOMGLy5jFj6ctDsn",
#     "explicit": false,
#     "preview": "https://p.scdn.co/mp3-preview/d8fd578f56458c000954181fcff4c5624f83a988?cid=1544e44f656f402894c4b6b4c0efdf9b",
#     "image": "https://i.scdn.co/image/ab67616d00001e02d61aa27a9efeb0049d1f77b6"
#   },
#   "10": {
#     "artist_name": "DEAN",
#     "song_name": "The Unknown Guest",
#     "id": "28WctYFXTOeQm4FTYgENyp",
#     "external_urls": "https://open.spotify.com/track/28WctYFXTOeQm4FTYgENyp",
#     "explicit": false,
#     "preview": "http://bit.ly/2nXRRfX",
#     "image": "https://i.scdn.co/image/ab67616d00001e029a4616cc6ce6c1aa0c265d8d"
#   }
# }

# %% [markdown]
# ### Create get audio features function

# %%
# Takes track id's and returns audio features for each id
def get_audio_features(track_ids):
    saved_tracks_audiofeat = [ ]
    
    # iterate through track_ids in groups of 50
    for ix in range(0,len(track_ids),50):
        audio_feats = sp.audio_features(track_ids[ix:ix+50])
        saved_tracks_audiofeat += audio_feats
        
    return saved_tracks_audiofeat

# %%
# test the function
bunch = ('4DRQBzgiM3SQqO5bXXPGpb', '3j5udcJCWrQK51O6wahLyf', '4FXHLmzOMGLy5jFj6ctDsn')

# %%
# it works
get_audio_features(bunch)
# Out:
# [{'danceability': 0.426,
#   'energy': 0.766,
#   'key': 0,
#   'loudness': -8.13,
#   'mode': 1,
#   'speechiness': 0.0894,
#   'acousticness': 0.0255,
#   'instrumentalness': 0.000808,
#   'liveness': 0.0931,
#   'valence': 0.345,
#   'tempo': 120.178,
#   'type': 'audio_features',
#   'id': '4DRQBzgiM3SQqO5bXXPGpb',
#   'uri': 'spotify:track:4DRQBzgiM3SQqO5bXXPGpb',
#   'track_href': 'https://api.spotify.com/v1/tracks/4DRQBzgiM3SQqO5bXXPGpb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DRQBzgiM3SQqO5bXXPGpb',
#   'duration_ms': 204720,
#   'time_signature': 4},
#  {'danceability': 0.48,
#   'energy': 0.889,
#   'key': 11,
#   'loudness': -2.413,
#   'mode': 0,
#   'speechiness': 0.0454,
#   'acousticness': 0.0672,
#   'instrumentalness': 2.93e-06,
#   'liveness': 0.0859,
#   'valence': 0.297,
#   'tempo': 129.985,
#   'type': 'audio_features',
#   'id': '3j5udcJCWrQK51O6wahLyf',
#   'uri': 'spotify:track:3j5udcJCWrQK51O6wahLyf',
#   'track_href': 'https://api.spotify.com/v1/tracks/3j5udcJCWrQK51O6wahLyf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3j5udcJCWrQK51O6wahLyf',
#   'duration_ms': 173538,
#   'time_signature': 4},
#  {'danceability': 0.586,
#   'energy': 0.528,
#   'key': 8,
#   'loudness': -7.62,
#   'mode': 0,
#   'speechiness': 0.274,
#   'acousticness': 0.641,
#   'instrumentalness': 0.641,
#   'liveness': 0.128,
#   'valence': 0.139,
#   'tempo': 73.973,
#   'type': 'audio_features',
#   'id': '4FXHLmzOMGLy5jFj6ctDsn',
#   'uri': 'spotify:track:4FXHLmzOMGLy5jFj6ctDsn',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FXHLmzOMGLy5jFj6ctDsn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FXHLmzOMGLy5jFj6ctDsn',
#   'duration_ms': 211597,
#   'time_signature': 1}]

# %%
# Let's test it on a real data
_audiofeat = get_audio_features(_track_df['id'])

# %%
df = pd.DataFrame(_audiofeat)
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.484   0.807   11    -5.386     1       0.0566       0.00299
# 1         0.323   0.405   10    -8.533     0       0.0413       0.84900
# 2         0.525   0.537    4    -8.071     0       0.0301       0.19800
# 3         0.426   0.766    0    -8.130     1       0.0894       0.02550
# 4         0.480   0.889   11    -2.413     0       0.0454       0.06720
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000012    0.1070    0.253  120.223  audio_features
# 1          0.000544    0.1380    0.274  145.104  audio_features
# 2          0.615000    0.1240    0.319   90.001  audio_features
# 3          0.000808    0.0931    0.345  120.178  audio_features
# 4          0.000003    0.0859    0.297  129.985  audio_features
#
#                        id                                   uri  \
# 0  0gxBrbuodVvvHyXtpXOun2  spotify:track:0gxBrbuodVvvHyXtpXOun2
# 1  3Z0oQ8r78OUaHvGPiDBR3W  spotify:track:3Z0oQ8r78OUaHvGPiDBR3W
# 2  7Eg9qnJK7hI7LLoRsbvH2X  spotify:track:7Eg9qnJK7hI7LLoRsbvH2X
# 3  4DRQBzgiM3SQqO5bXXPGpb  spotify:track:4DRQBzgiM3SQqO5bXXPGpb
# 4  3j5udcJCWrQK51O6wahLyf  spotify:track:3j5udcJCWrQK51O6wahLyf
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0gxBrbuodVvv...
# 1  https://api.spotify.com/v1/tracks/3Z0oQ8r78OUa...
# 2  https://api.spotify.com/v1/tracks/7Eg9qnJK7hI7...
# 3  https://api.spotify.com/v1/tracks/4DRQBzgiM3SQ...
# 4  https://api.spotify.com/v1/tracks/3j5udcJCWrQK...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0gxB...       180592
# 1  https://api.spotify.com/v1/audio-analysis/3Z0o...       194848
# 2  https://api.spotify.com/v1/audio-analysis/7Eg9...       179120
# 3  https://api.spotify.com/v1/audio-analysis/4DRQ...       204720
# 4  https://api.spotify.com/v1/audio-analysis/3j5u...       173538
#
#    time_signature
# 0               4
# 1               5
# 2               4
# 3               4
# 4               4

# %%
df_1 = df.drop(['analysis_url', 'track_href', 'type', 'uri'], axis = 1)
df_1.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.484   0.807   11    -5.386     1       0.0566       0.00299
# 1         0.323   0.405   10    -8.533     0       0.0413       0.84900
# 2         0.525   0.537    4    -8.071     0       0.0301       0.19800
# 3         0.426   0.766    0    -8.130     1       0.0894       0.02550
# 4         0.480   0.889   11    -2.413     0       0.0454       0.06720
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000012    0.1070    0.253  120.223  0gxBrbuodVvvHyXtpXOun2
# 1          0.000544    0.1380    0.274  145.104  3Z0oQ8r78OUaHvGPiDBR3W
# 2          0.615000    0.1240    0.319   90.001  7Eg9qnJK7hI7LLoRsbvH2X
# 3          0.000808    0.0931    0.345  120.178  4DRQBzgiM3SQqO5bXXPGpb
# 4          0.000003    0.0859    0.297  129.985  3j5udcJCWrQK51O6wahLyf
#
#    duration_ms  time_signature
# 0       180592               4
# 1       194848               5
# 2       179120               4
# 3       204720               4
# 4       173538               4

# %%
# Drop the repeats and unnecessary data
_audiofeat_df = pd.DataFrame(_audiofeat).drop(['analysis_url', 'track_href', 'type', 'uri'], axis = 1)

# %%
_audiofeat_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.484   0.807   11    -5.386     1       0.0566       0.00299
# 1         0.323   0.405   10    -8.533     0       0.0413       0.84900
# 2         0.525   0.537    4    -8.071     0       0.0301       0.19800
# 3         0.426   0.766    0    -8.130     1       0.0894       0.02550
# 4         0.480   0.889   11    -2.413     0       0.0454       0.06720
# 5         0.739   0.240    6    -9.809     1       0.0468       0.53800
# 6         0.456   0.828    1    -6.225     1       0.0770       0.02440
# 7         0.461   0.367    2   -13.850     1       0.1040       0.29100
# 8         0.586   0.528    8    -7.620     0       0.2740       0.64100
# 9         0.377   0.199    4   -16.499     1       0.0448       0.95200
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000012    0.1070    0.253  120.223  0gxBrbuodVvvHyXtpXOun2
# 1          0.000544    0.1380    0.274  145.104  3Z0oQ8r78OUaHvGPiDBR3W
# 2          0.615000    0.1240    0.319   90.001  7Eg9qnJK7hI7LLoRsbvH2X
# 3          0.000808    0.0931    0.345  120.178  4DRQBzgiM3SQqO5bXXPGpb
# 4          0.000003    0.0859    0.297  129.985  3j5udcJCWrQK51O6wahLyf
# 5          0.000131    0.2440    0.179  117.282  3TQerxyGsmsmGaWb0J7uhg
# 6          0.000000    0.2100    0.313  116.719  421eObjg0DTm2qajJl5OJm
# 7          0.021600    0.3660    0.671  115.717  78JYtz4yOPqAEgZZc3SBLT
# 8          0.641000    0.1280    0.139   73.973  4FXHLmzOMGLy5jFj6ctDsn
# 9          0.000030    0.1710    0.340  112.987  28WctYFXTOeQm4FTYgENyp
#
#    duration_ms  time_signature
# 0       180592               4
# 1       194848               5
# 2       179120               4
# 3       204720               4
# 4       173538               4
# 5        69197               4
# 6       189132               4
# 7       201107               4
# 8       211597               1
# 9       116759               3

# %%
# Merge two dataframes on 'id'
tracks_plus_df = _track_df.merge(_audiofeat_df, how = 'left', left_on = 'id', right_on = 'id')

# %%
tracks_plus_df.head()
# Out:
#        artist_name         song_name                      id  \
# 0         10 Years       The Unknown  0gxBrbuodVvvHyXtpXOun2
# 1     Idina Menzel  Into the Unknown  3Z0oQ8r78OUaHvGPiDBR3W
# 2        Crossfade       The Unknown  7Eg9qnJK7hI7LLoRsbvH2X
# 3  Imagine Dragons       The Unknown  4DRQBzgiM3SQqO5bXXPGpb
# 4   BONNIE X CLYDE       The Unknown  3j5udcJCWrQK51O6wahLyf
#
#                                        external_urls  explicit  \
# 0  https://open.spotify.com/track/0gxBrbuodVvvHyX...     False
# 1  https://open.spotify.com/track/3Z0oQ8r78OUaHvG...     False
# 2  https://open.spotify.com/track/7Eg9qnJK7hI7LLo...     False
# 3  https://open.spotify.com/track/4DRQBzgiM3SQqO5...     False
# 4  https://open.spotify.com/track/3j5udcJCWrQK51O...     False
#
#                                              preview  \
# 0  https://p.scdn.co/mp3-preview/ee2b37855716c77f...
# 1                              http://bit.ly/2nXRRfX
# 2  https://p.scdn.co/mp3-preview/0f95c28210930bcb...
# 3                              http://bit.ly/2nXRRfX
# 4  https://p.scdn.co/mp3-preview/81ce4a86d980c7e5...
#
#                                                image  danceability  energy  \
# 0  https://i.scdn.co/image/ab67616d00001e0242cbef...         0.484   0.807
# 1  https://i.scdn.co/image/ab67616d00001e026ff59d...         0.323   0.405
# 2  https://i.scdn.co/image/ab67616d00001e026655dc...         0.525   0.537
# 3  https://i.scdn.co/image/ab67616d00001e021551c9...         0.426   0.766
# 4  https://i.scdn.co/image/ab67616d00001e02606ad3...         0.480   0.889
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   11    -5.386     1       0.0566       0.00299          0.000012    0.1070
# 1   10    -8.533     0       0.0413       0.84900          0.000544    0.1380
# 2    4    -8.071     0       0.0301       0.19800          0.615000    0.1240
# 3    0    -8.130     1       0.0894       0.02550          0.000808    0.0931
# 4   11    -2.413     0       0.0454       0.06720          0.000003    0.0859
#
#    valence    tempo  duration_ms  time_signature
# 0    0.253  120.223       180592               4
# 1    0.274  145.104       194848               5
# 2    0.319   90.001       179120               4
# 3    0.345  120.178       204720               4
# 4    0.297  129.985       173538               4

# %% [markdown]
# ### Final result

# %%
tracks_plus_df.index += 1

# %%
tracks_plus_df
# Out:
#             artist_name                                       song_name  \
# 1              10 Years                                     The Unknown
# 2          Idina Menzel                                Into the Unknown
# 3             Crossfade                                     The Unknown
# 4       Imagine Dragons                                     The Unknown
# 5        BONNIE X CLYDE                                     The Unknown
# 6           Twoxxtremes                                     The Unknown
# 7   Panic! At The Disco  Into the Unknown - Panic! At The Disco Version
# 8             The Doors                             The Unknown Soldier
# 9                 ford.                                     The Unknown
# 10                 DEAN                               The Unknown Guest
#
#                         id                                      external_urls  \
# 1   0gxBrbuodVvvHyXtpXOun2  https://open.spotify.com/track/0gxBrbuodVvvHyX...
# 2   3Z0oQ8r78OUaHvGPiDBR3W  https://open.spotify.com/track/3Z0oQ8r78OUaHvG...
# 3   7Eg9qnJK7hI7LLoRsbvH2X  https://open.spotify.com/track/7Eg9qnJK7hI7LLo...
# 4   4DRQBzgiM3SQqO5bXXPGpb  https://open.spotify.com/track/4DRQBzgiM3SQqO5...
# 5   3j5udcJCWrQK51O6wahLyf  https://open.spotify.com/track/3j5udcJCWrQK51O...
# 6   3TQerxyGsmsmGaWb0J7uhg  https://open.spotify.com/track/3TQerxyGsmsmGaW...
# 7   421eObjg0DTm2qajJl5OJm  https://open.spotify.com/track/421eObjg0DTm2qa...
# 8   78JYtz4yOPqAEgZZc3SBLT  https://open.spotify.com/track/78JYtz4yOPqAEgZ...
# 9   4FXHLmzOMGLy5jFj6ctDsn  https://open.spotify.com/track/4FXHLmzOMGLy5jF...
# 10  28WctYFXTOeQm4FTYgENyp  https://open.spotify.com/track/28WctYFXTOeQm4F...
#
#     explicit                                            preview  \
# 1      False  https://p.scdn.co/mp3-preview/ee2b37855716c77f...
# 2      False                              http://bit.ly/2nXRRfX
# 3      False  https://p.scdn.co/mp3-preview/0f95c28210930bcb...
# 4      False                              http://bit.ly/2nXRRfX
# 5      False  https://p.scdn.co/mp3-preview/81ce4a86d980c7e5...
# 6       True  https://p.scdn.co/mp3-preview/0c2ef5df7ae75680...
# 7      False                              http://bit.ly/2nXRRfX
# 8      False  https://p.scdn.co/mp3-preview/c2771fe651f4c1b4...
# 9      False  https://p.scdn.co/mp3-preview/d8fd578f56458c00...
# 10     False                              http://bit.ly/2nXRRfX
#
#                                                 image  danceability  energy  \
# 1   https://i.scdn.co/image/ab67616d00001e0242cbef...         0.484   0.807
# 2   https://i.scdn.co/image/ab67616d00001e026ff59d...         0.323   0.405
# 3   https://i.scdn.co/image/ab67616d00001e026655dc...         0.525   0.537
# 4   https://i.scdn.co/image/ab67616d00001e021551c9...         0.426   0.766
# 5   https://i.scdn.co/image/ab67616d00001e02606ad3...         0.480   0.889
# 6   https://i.scdn.co/image/ab67616d00001e024121c1...         0.739   0.240
# 7   https://i.scdn.co/image/ab67616d00001e026ff59d...         0.456   0.828
# 8   https://i.scdn.co/image/ab67616d00001e023f695b...         0.461   0.367
# 9   https://i.scdn.co/image/ab67616d00001e02d61aa2...         0.586   0.528
# 10  https://i.scdn.co/image/ab67616d00001e029a4616...         0.377   0.199
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 1    11    -5.386     1       0.0566       0.00299          0.000012
# 2    10    -8.533     0       0.0413       0.84900          0.000544
# 3     4    -8.071     0       0.0301       0.19800          0.615000
# 4     0    -8.130     1       0.0894       0.02550          0.000808
# 5    11    -2.413     0       0.0454       0.06720          0.000003
# 6     6    -9.809     1       0.0468       0.53800          0.000131
# 7     1    -6.225     1       0.0770       0.02440          0.000000
# 8     2   -13.850     1       0.1040       0.29100          0.021600
# 9     8    -7.620     0       0.2740       0.64100          0.641000
# 10    4   -16.499     1       0.0448       0.95200          0.000030
#
#     liveness  valence    tempo  duration_ms  time_signature
# 1     0.1070    0.253  120.223       180592               4
# 2     0.1380    0.274  145.104       194848               5
# 3     0.1240    0.319   90.001       179120               4
# 4     0.0931    0.345  120.178       204720               4
# 5     0.0859    0.297  129.985       173538               4
# 6     0.2440    0.179  117.282        69197               4
# 7     0.2100    0.313  116.719       189132               4
# 8     0.3660    0.671  115.717       201107               4
# 9     0.1280    0.139   73.973       211597               1
# 10    0.1710    0.340  112.987       116759               3
