# %% [markdown]
# ## Create a token to use for Spotify queries

# %% [markdown]
# ### Load Libraries

# %%
import spotipy
import spotipy.util as util
import sys
import requests
from dotenv import load_dotenv
import os

# %%
load_dotenv() # load environment variables
# Out:
# True

# %% [markdown]
# ### Load Spotify variables

# %%
SEARCH_ENDPOINT = 'https://api.spotify.com/v1/search'
CLIENT_ID = os.getenv('SPOTIPY_CLIENT_ID', default="OOPS")
CLIENT_SECRET = os.getenv('SPOTIPY_CLIENT_SECRET', default="OOPS")

# %% [markdown]
# ### Load client credentials to create a token

# %%
data = {'grant_type': 'client_credentials'}
url = 'https://accounts.spotify.com/api/token'
response = requests.post(url, data=data, auth=(CLIENT_ID, CLIENT_SECRET))
token = response.json()['access_token']

# %% [markdown]
# #### You can print it out to check if code works

# %%
# print(token)
# print(response.json()['access_token'])

# %% [markdown]
# ### Check how token performs

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer {}'.format(token)
}

# %%
params = (
        ('type', 'track'),
        ('limit', 5)
)

# %%
song_track = 'the unknown' # song name, choose any

# %%
song = requests.get("https://api.spotify.com/v1/search?q="+ song_track + "&type=track",
                   headers=headers, params=params)

# %% [markdown]
# ### Other way of doing it

# %%
name = song_track

# %%
myparams = {'type': 'track', 'limit': 10}
myparams['q'] = name
resp = requests.get(SEARCH_ENDPOINT, headers=headers, params=myparams)

# %% [markdown]
# ### Check for response '200'

# %%
song
# Out:
# <Response [200]>

# %%
resp
# Out:
# <Response [200]>

# %% [markdown]
# ### You have plenty of features to choose from

# %%
print(song.json())
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=0&limit=5', 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph'}, 'href': 'https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph', 'id': '0REMf7H0VP6DwfZ9MbuWph', 'name': '10 Years', 'type': 'artist', 'uri': 'spotify:artist:0REMf7H0VP6DwfZ9MbuWph'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0qFOyJ2NsyTjgWXYGPAZxM'}, 'href': 'https://api.spotify.com/v1/albums/0qFOyJ2NsyTjgWXYGPAZxM', 'id': '0qFOyJ2NsyTjgWXYGPAZxM', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27342cbef66db5480fc654a327b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485142cbef66db5480fc654a327b', 'width': 64}], 'name': 'The Unknown', 'release_date': '2020-07-10', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:0qFOyJ2NsyTjgWXYGPAZxM'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph'}, 'href': 'https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph', 'id': '0REMf7H0VP6DwfZ9MbuWph', 'name': '10 Years', 'type': 'artist', 'uri': 'spotify:artist:0REMf7H0VP6DwfZ9MbuWph'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 180592, 'explicit': False, 'external_ids': {'isrc': 'NLB932001702'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2'}, 'href': 'https://api.spotify.com/v1/tracks/0gxBrbuodVvvHyXtpXOun2', 'id': '0gxBrbuodVvvHyXtpXOun2', 'is_local': False, 'name': 'The Unknown', 'popularity': 49, 'preview_url': 'https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:0gxBrbuodVvvHyXtpXOun2'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US ...

# %%
print(resp.text)
# Out:
# {
#   "tracks" : {
#     "href" : "https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=0&limit=10",
#     "items" : [ {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph",
#           "id" : "0REMf7H0VP6DwfZ9MbuWph",
#           "name" : "10 Years",
#           "type" : "artist",
#           "uri" : "spotify:artist:0REMf7H0VP6DwfZ9MbuWph"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0qFOyJ2NsyTjgWXYGPAZxM"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0qFOyJ2NsyTjgWXYGPAZxM",
#         "id" : "0qFOyJ2NsyTjgWXYGPAZxM",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b27342cbef66db5480fc654a327b",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e0242cbef66db5480fc654a327b",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d0000485142cbef66db5480fc654a327b",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2020-07-10",
#         "release_date_precision" : "day",
#         "total_tracks" : 2,
#         "type" : "album",
#         "uri" : "spotify:album:0qFOyJ2NsyTjgWXYGPAZxM"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/0REMf7H0VP6DwfZ9MbuWph"
#         },
#         "href" : "https://api.spotify.com/v1/artists/0REMf7H0VP6DwfZ9MbuWph",
#         "id" : "0REMf7H0VP6DwfZ9MbuWph",
#         "name" : "10 Years",
#         "type" : "artist",
#         "uri" : "spotify:artist:0REMf7H0VP6DwfZ9MbuWph"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 180592,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "NLB932001702"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/0gxBrbuodVvvHyXtpXOun2",
#       "id" : "0gxBrbuodVvvHyXtpXOun2",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 49,
#       "preview_url" : "https://p.scdn.co/mp3-preview/ee2b37855716c77f13d4aaf29e3acb065a94e801?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:0gxBrbuodVvvHyXtpXOun2"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#           "id" : "0LyfQWJT6nXafLPZqxe9Of",
#           "name" : "Various Artists",
#           "type" : "artist",
#           "uri" : "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/4M07HWIlZr7zoXoxDHR5mz"
#         },
#         "href" : "https://api.spotify.com/v1/albums/4M07HWIlZr7zoXoxDHR5mz",
#         "id" : "4M07HWIlZr7zoXoxDHR5mz",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736ff59d18c018a2845758deed",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516ff59d18c018a2845758deed",
#           "width" : 64
#         } ],
#         "name" : "Frozen 2 (Original Motion Picture Soundtrack/Deluxe Edition)",
#         "release_date" : "2019-11-15",
#         "release_date_precision" : "day",
#         "total_tracks" : 46,
#         "type" : "album",
#         "uri" : "spotify:album:4M07HWIlZr7zoXoxDHR5mz"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/73Np75Wv2tju61Eo9Zw4IR"
#         },
#         "href" : "https://api.spotify.com/v1/artists/73Np75Wv2tju61Eo9Zw4IR",
#         "id" : "73Np75Wv2tju61Eo9Zw4IR",
#         "name" : "Idina Menzel",
#         "type" : "artist",
#         "uri" : "spotify:artist:73Np75Wv2tju61Eo9Zw4IR"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N",
#         "id" : "1WgXqy2Dd70QQOU7Ay074N",
#         "name" : "AURORA",
#         "type" : "artist",
#         "uri" : "spotify:artist:1WgXqy2Dd70QQOU7Ay074N"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 194848,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USWD11994667"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3Z0oQ8r78OUaHvGPiDBR3W"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3Z0oQ8r78OUaHvGPiDBR3W",
#       "id" : "3Z0oQ8r78OUaHvGPiDBR3W",
#       "is_local" : false,
#       "name" : "Into the Unknown",
#       "popularity" : 79,
#       "preview_url" : null,
#       "track_number" : 3,
#       "type" : "track",
#       "uri" : "spotify:track:3Z0oQ8r78OUaHvGPiDBR3W"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/4IR8ZkpbyyKrqsIzchF3NB"
#           },
#           "href" : "https://api.spotify.com/v1/artists/4IR8ZkpbyyKrqsIzchF3NB",
#           "id" : "4IR8ZkpbyyKrqsIzchF3NB",
#           "name" : "Crossfade",
#           "type" : "artist",
#           "uri" : "spotify:artist:4IR8ZkpbyyKrqsIzchF3NB"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/1namjaJZ23ozXXB7X2d4hy"
#         },
#         "href" : "https://api.spotify.com/v1/albums/1namjaJZ23ozXXB7X2d4hy",
#         "id" : "1namjaJZ23ozXXB7X2d4hy",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736655dcd1e8b57d0022f856e6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026655dcd1e8b57d0022f856e6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516655dcd1e8b57d0022f856e6",
#           "width" : 64
#         } ],
#         "name" : "Crossfade",
#         "release_date" : "2004-04-13",
#         "release_date_precision" : "day",
#         "total_tracks" : 10,
#         "type" : "album",
#         "uri" : "spotify:album:1namjaJZ23ozXXB7X2d4hy"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/4IR8ZkpbyyKrqsIzchF3NB"
#         },
#         "href" : "https://api.spotify.com/v1/artists/4IR8ZkpbyyKrqsIzchF3NB",
#         "id" : "4IR8ZkpbyyKrqsIzchF3NB",
#         "name" : "Crossfade",
#         "type" : "artist",
#         "uri" : "spotify:artist:4IR8ZkpbyyKrqsIzchF3NB"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 179120,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USSM10400177"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/7Eg9qnJK7hI7LLoRsbvH2X"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/7Eg9qnJK7hI7LLoRsbvH2X",
#       "id" : "7Eg9qnJK7hI7LLoRsbvH2X",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 46,
#       "preview_url" : "https://p.scdn.co/mp3-preview/0f95c28210930bcb4cbd7100d122c24412d42c87?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 10,
#       "type" : "track",
#       "uri" : "spotify:track:7Eg9qnJK7hI7LLoRsbvH2X"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q"
#           },
#           "href" : "https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q",
#           "id" : "53XhwfbYqKCa1cC15pYq2q",
#           "name" : "Imagine Dragons",
#           "type" : "artist",
#           "uri" : "spotify:artist:53XhwfbYqKCa1cC15pYq2q"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HN", "HR", "HU", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SI", "SK", "SV", "TN", "TR", "UA", "US", "UY", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6ecx4OFG0nlUMqAi9OXQER"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6ecx4OFG0nlUMqAi9OXQER",
#         "id" : "6ecx4OFG0nlUMqAi9OXQER",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2731551c93dfa33ea4f30ef4eea",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e021551c93dfa33ea4f30ef4eea",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048511551c93dfa33ea4f30ef4eea",
#           "width" : 64
#         } ],
#         "name" : "Smoke + Mirrors (Deluxe)",
#         "release_date" : "2015-10-30",
#         "release_date_precision" : "day",
#         "total_tracks" : 21,
#         "type" : "album",
#         "uri" : "spotify:album:6ecx4OFG0nlUMqAi9OXQER"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q"
#         },
#         "href" : "https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q",
#         "id" : "53XhwfbYqKCa1cC15pYq2q",
#         "name" : "Imagine Dragons",
#         "type" : "artist",
#         "uri" : "spotify:artist:53XhwfbYqKCa1cC15pYq2q"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HN", "HR", "HU", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SI", "SK", "SV", "TN", "TR", "UA", "US", "UY", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 204720,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USUM71417940"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/4DRQBzgiM3SQqO5bXXPGpb"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/4DRQBzgiM3SQqO5bXXPGpb",
#       "id" : "4DRQBzgiM3SQqO5bXXPGpb",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 45,
#       "preview_url" : null,
#       "track_number" : 15,
#       "type" : "track",
#       "uri" : "spotify:track:4DRQBzgiM3SQqO5bXXPGpb"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/74xeHqz5Ap8ZHq69TkxI0r"
#           },
#           "href" : "https://api.spotify.com/v1/artists/74xeHqz5Ap8ZHq69TkxI0r",
#           "id" : "74xeHqz5Ap8ZHq69TkxI0r",
#           "name" : "BONNIE X CLYDE",
#           "type" : "artist",
#           "uri" : "spotify:artist:74xeHqz5Ap8ZHq69TkxI0r"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6akNhXVhvX9OySiINEyXCF"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6akNhXVhvX9OySiINEyXCF",
#         "id" : "6akNhXVhvX9OySiINEyXCF",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b273606ad337bb83dc55c3698b36",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e02606ad337bb83dc55c3698b36",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d00004851606ad337bb83dc55c3698b36",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2018-05-11",
#         "release_date_precision" : "day",
#         "total_tracks" : 1,
#         "type" : "album",
#         "uri" : "spotify:album:6akNhXVhvX9OySiINEyXCF"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/74xeHqz5Ap8ZHq69TkxI0r"
#         },
#         "href" : "https://api.spotify.com/v1/artists/74xeHqz5Ap8ZHq69TkxI0r",
#         "id" : "74xeHqz5Ap8ZHq69TkxI0r",
#         "name" : "BONNIE X CLYDE",
#         "type" : "artist",
#         "uri" : "spotify:artist:74xeHqz5Ap8ZHq69TkxI0r"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 173538,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "TCADP1871048"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3j5udcJCWrQK51O6wahLyf"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3j5udcJCWrQK51O6wahLyf",
#       "id" : "3j5udcJCWrQK51O6wahLyf",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 45,
#       "preview_url" : "https://p.scdn.co/mp3-preview/81ce4a86d980c7e5e5d9ac1cd8302ebf938aa481?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:3j5udcJCWrQK51O6wahLyf"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/7ur5xQmbRVw7992qVyfjRM"
#           },
#           "href" : "https://api.spotify.com/v1/artists/7ur5xQmbRVw7992qVyfjRM",
#           "id" : "7ur5xQmbRVw7992qVyfjRM",
#           "name" : "Twoxxtremes",
#           "type" : "artist",
#           "uri" : "spotify:artist:7ur5xQmbRVw7992qVyfjRM"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/6UXFTAmyGkpZbyZpiOFjBt"
#         },
#         "href" : "https://api.spotify.com/v1/albums/6UXFTAmyGkpZbyZpiOFjBt",
#         "id" : "6UXFTAmyGkpZbyZpiOFjBt",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2734121c143b34ebfb5936689e6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e024121c143b34ebfb5936689e6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048514121c143b34ebfb5936689e6",
#           "width" : 64
#         } ],
#         "name" : "X.X.",
#         "release_date" : "2019-08-05",
#         "release_date_precision" : "day",
#         "total_tracks" : 5,
#         "type" : "album",
#         "uri" : "spotify:album:6UXFTAmyGkpZbyZpiOFjBt"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/7ur5xQmbRVw7992qVyfjRM"
#         },
#         "href" : "https://api.spotify.com/v1/artists/7ur5xQmbRVw7992qVyfjRM",
#         "id" : "7ur5xQmbRVw7992qVyfjRM",
#         "name" : "Twoxxtremes",
#         "type" : "artist",
#         "uri" : "spotify:artist:7ur5xQmbRVw7992qVyfjRM"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 69197,
#       "explicit" : true,
#       "external_ids" : {
#         "isrc" : "QZFZ61914748"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/3TQerxyGsmsmGaWb0J7uhg"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/3TQerxyGsmsmGaWb0J7uhg",
#       "id" : "3TQerxyGsmsmGaWb0J7uhg",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 37,
#       "preview_url" : "https://p.scdn.co/mp3-preview/0c2ef5df7ae756805ac3c17750f5600a3e943a67?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 5,
#       "type" : "track",
#       "uri" : "spotify:track:3TQerxyGsmsmGaWb0J7uhg"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of"
#           },
#           "href" : "https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of",
#           "id" : "0LyfQWJT6nXafLPZqxe9Of",
#           "name" : "Various Artists",
#           "type" : "artist",
#           "uri" : "spotify:artist:0LyfQWJT6nXafLPZqxe9Of"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/4M07HWIlZr7zoXoxDHR5mz"
#         },
#         "href" : "https://api.spotify.com/v1/albums/4M07HWIlZr7zoXoxDHR5mz",
#         "id" : "4M07HWIlZr7zoXoxDHR5mz",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2736ff59d18c018a2845758deed",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e026ff59d18c018a2845758deed",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048516ff59d18c018a2845758deed",
#           "width" : 64
#         } ],
#         "name" : "Frozen 2 (Original Motion Picture Soundtrack/Deluxe Edition)",
#         "release_date" : "2019-11-15",
#         "release_date_precision" : "day",
#         "total_tracks" : 46,
#         "type" : "album",
#         "uri" : "spotify:album:4M07HWIlZr7zoXoxDHR5mz"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/20JZFwl6HVl6yg8a4H3ZqK"
#         },
#         "href" : "https://api.spotify.com/v1/artists/20JZFwl6HVl6yg8a4H3ZqK",
#         "id" : "20JZFwl6HVl6yg8a4H3ZqK",
#         "name" : "Panic! At The Disco",
#         "type" : "artist",
#         "uri" : "spotify:artist:20JZFwl6HVl6yg8a4H3ZqK"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 189132,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USWD11994800"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/421eObjg0DTm2qajJl5OJm"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/421eObjg0DTm2qajJl5OJm",
#       "id" : "421eObjg0DTm2qajJl5OJm",
#       "is_local" : false,
#       "name" : "Into the Unknown - Panic! At The Disco Version",
#       "popularity" : 75,
#       "preview_url" : null,
#       "track_number" : 9,
#       "type" : "track",
#       "uri" : "spotify:track:421eObjg0DTm2qajJl5OJm"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18"
#           },
#           "href" : "https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18",
#           "id" : "7ItbAZITSFxSy5LJChXe18",
#           "name" : "ford.",
#           "type" : "artist",
#           "uri" : "spotify:artist:7ItbAZITSFxSy5LJChXe18"
#         }, {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/1eL4DVwObeAZjGOVjASAXd"
#           },
#           "href" : "https://api.spotify.com/v1/artists/1eL4DVwObeAZjGOVjASAXd",
#           "id" : "1eL4DVwObeAZjGOVjASAXd",
#           "name" : "Hanz",
#           "type" : "artist",
#           "uri" : "spotify:artist:1eL4DVwObeAZjGOVjASAXd"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0Mly9ByCUByZRYCLZkEtqf"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0Mly9ByCUByZRYCLZkEtqf",
#         "id" : "0Mly9ByCUByZRYCLZkEtqf",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b273d61aa27a9efeb0049d1f77b6",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e02d61aa27a9efeb0049d1f77b6",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d00004851d61aa27a9efeb0049d1f77b6",
#           "width" : 64
#         } ],
#         "name" : "The Unknown",
#         "release_date" : "2018-03-16",
#         "release_date_precision" : "day",
#         "total_tracks" : 1,
#         "type" : "album",
#         "uri" : "spotify:album:0Mly9ByCUByZRYCLZkEtqf"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/7ItbAZITSFxSy5LJChXe18"
#         },
#         "href" : "https://api.spotify.com/v1/artists/7ItbAZITSFxSy5LJChXe18",
#         "id" : "7ItbAZITSFxSy5LJChXe18",
#         "name" : "ford.",
#         "type" : "artist",
#         "uri" : "spotify:artist:7ItbAZITSFxSy5LJChXe18"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1eL4DVwObeAZjGOVjASAXd"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1eL4DVwObeAZjGOVjASAXd",
#         "id" : "1eL4DVwObeAZjGOVjASAXd",
#         "name" : "Hanz",
#         "type" : "artist",
#         "uri" : "spotify:artist:1eL4DVwObeAZjGOVjASAXd"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/5aNJpeK3hUdPY9orfExdOF"
#         },
#         "href" : "https://api.spotify.com/v1/artists/5aNJpeK3hUdPY9orfExdOF",
#         "id" : "5aNJpeK3hUdPY9orfExdOF",
#         "name" : "Ayelle",
#         "type" : "artist",
#         "uri" : "spotify:artist:5aNJpeK3hUdPY9orfExdOF"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 211596,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "TCADN1813258"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/4FXHLmzOMGLy5jFj6ctDsn"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/4FXHLmzOMGLy5jFj6ctDsn",
#       "id" : "4FXHLmzOMGLy5jFj6ctDsn",
#       "is_local" : false,
#       "name" : "The Unknown",
#       "popularity" : 42,
#       "preview_url" : "https://p.scdn.co/mp3-preview/d8fd578f56458c000954181fcff4c5624f83a988?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:4FXHLmzOMGLy5jFj6ctDsn"
#     }, {
#       "album" : {
#         "album_type" : "album",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt"
#           },
#           "href" : "https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt",
#           "id" : "22WZ7M8sxp5THdruNY3gXt",
#           "name" : "The Doors",
#           "type" : "artist",
#           "uri" : "spotify:artist:22WZ7M8sxp5THdruNY3gXt"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/0qZTwrunzX3LG45PvRghmh"
#         },
#         "href" : "https://api.spotify.com/v1/albums/0qZTwrunzX3LG45PvRghmh",
#         "id" : "0qZTwrunzX3LG45PvRghmh",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2733f695bca9b4a89457e42ce22",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e023f695bca9b4a89457e42ce22",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048513f695bca9b4a89457e42ce22",
#           "width" : 64
#         } ],
#         "name" : "Waiting for the Sun",
#         "release_date" : "1968-07-03",
#         "release_date_precision" : "day",
#         "total_tracks" : 11,
#         "type" : "album",
#         "uri" : "spotify:album:0qZTwrunzX3LG45PvRghmh"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt"
#         },
#         "href" : "https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt",
#         "id" : "22WZ7M8sxp5THdruNY3gXt",
#         "name" : "The Doors",
#         "type" : "artist",
#         "uri" : "spotify:artist:22WZ7M8sxp5THdruNY3gXt"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 201106,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "USEE19900749"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/78JYtz4yOPqAEgZZc3SBLT"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/78JYtz4yOPqAEgZZc3SBLT",
#       "id" : "78JYtz4yOPqAEgZZc3SBLT",
#       "is_local" : false,
#       "name" : "The Unknown Soldier",
#       "popularity" : 49,
#       "preview_url" : "https://p.scdn.co/mp3-preview/c2771fe651f4c1b4906df856e354cb7f7071fbd2?cid=1544e44f656f402894c4b6b4c0efdf9b",
#       "track_number" : 6,
#       "type" : "track",
#       "uri" : "spotify:track:78JYtz4yOPqAEgZZc3SBLT"
#     }, {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/3eCd0TZrBPm2n9cDG6yWfF"
#           },
#           "href" : "https://api.spotify.com/v1/artists/3eCd0TZrBPm2n9cDG6yWfF",
#           "id" : "3eCd0TZrBPm2n9cDG6yWfF",
#           "name" : "DEAN",
#           "type" : "artist",
#           "uri" : "spotify:artist:3eCd0TZrBPm2n9cDG6yWfF"
#         } ],
#         "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/album/48ScAfcD1Dy3gMPhjhTzek"
#         },
#         "href" : "https://api.spotify.com/v1/albums/48ScAfcD1Dy3gMPhjhTzek",
#         "id" : "48ScAfcD1Dy3gMPhjhTzek",
#         "images" : [ {
#           "height" : 640,
#           "url" : "https://i.scdn.co/image/ab67616d0000b2739a4616cc6ce6c1aa0c265d8d",
#           "width" : 640
#         }, {
#           "height" : 300,
#           "url" : "https://i.scdn.co/image/ab67616d00001e029a4616cc6ce6c1aa0c265d8d",
#           "width" : 300
#         }, {
#           "height" : 64,
#           "url" : "https://i.scdn.co/image/ab67616d000048519a4616cc6ce6c1aa0c265d8d",
#           "width" : 64
#         } ],
#         "name" : "Limbo",
#         "release_date" : "2017-02-17",
#         "release_date_precision" : "day",
#         "total_tracks" : 2,
#         "type" : "album",
#         "uri" : "spotify:album:48ScAfcD1Dy3gMPhjhTzek"
#       },
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3eCd0TZrBPm2n9cDG6yWfF"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3eCd0TZrBPm2n9cDG6yWfF",
#         "id" : "3eCd0TZrBPm2n9cDG6yWfF",
#         "name" : "DEAN",
#         "type" : "artist",
#         "uri" : "spotify:artist:3eCd0TZrBPm2n9cDG6yWfF"
#       } ],
#       "available_markets" : [ "AD", "AE", "AL", "AR", "AT", "AU", "BA", "BE", "BG", "BH", "BO", "BR", "BY", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HR", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "KZ", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MD", "ME", "MK", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "RS", "RU", "SA", "SE", "SG", "SI", "SK", "SV", "TH", "TN", "TR", "TW", "UA", "US", "UY", "VN", "XK", "ZA" ],
#       "disc_number" : 1,
#       "duration_ms" : 116758,
#       "explicit" : false,
#       "external_ids" : {
#         "isrc" : "KRUM71700060"
#       },
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/track/28WctYFXTOeQm4FTYgENyp"
#       },
#       "href" : "https://api.spotify.com/v1/tracks/28WctYFXTOeQm4FTYgENyp",
#       "id" : "28WctYFXTOeQm4FTYgENyp",
#       "is_local" : false,
#       "name" : "The Unknown Guest",
#       "popularity" : 45,
#       "preview_url" : null,
#       "track_number" : 1,
#       "type" : "track",
#       "uri" : "spotify:track:28WctYFXTOeQm4FTYgENyp"
#     } ],
#     "limit" : 10,
#     "next" : "https://api.spotify.com/v1/search?query=the+unknown&type=track&offset=10&limit=10",
#     "offset" : 0,
#     "previous" : null,
#     "total" : 29036
#   }
# }

# %% [markdown]
# ### You can enumerate through them

# %%
res = resp.json() # transform the 200 result in to json file first

# %%
for i, track in enumerate(res['tracks']['items']):
    print(' ', i, track['name'],'-', track['artists'][0]['name'], '-', track['id'],
         '-', track['external_urls']['spotify'], '-', track['explicit'])
# Out:
#   0 The Unknown - 10 Years - 0gxBrbuodVvvHyXtpXOun2 - https://open.spotify.com/track/0gxBrbuodVvvHyXtpXOun2 - False
#   1 Into the Unknown - Idina Menzel - 3Z0oQ8r78OUaHvGPiDBR3W - https://open.spotify.com/track/3Z0oQ8r78OUaHvGPiDBR3W - False
#   2 The Unknown - Crossfade - 7Eg9qnJK7hI7LLoRsbvH2X - https://open.spotify.com/track/7Eg9qnJK7hI7LLoRsbvH2X - False
#   3 The Unknown - Imagine Dragons - 4DRQBzgiM3SQqO5bXXPGpb - https://open.spotify.com/track/4DRQBzgiM3SQqO5bXXPGpb - False
#   4 The Unknown - BONNIE X CLYDE - 3j5udcJCWrQK51O6wahLyf - https://open.spotify.com/track/3j5udcJCWrQK51O6wahLyf - False
#   5 The Unknown - Twoxxtremes - 3TQerxyGsmsmGaWb0J7uhg - https://open.spotify.com/track/3TQerxyGsmsmGaWb0J7uhg - True
#   6 Into the Unknown - Panic! At The Disco Version - Panic! At The Disco - 421eObjg0DTm2qajJl5OJm - https://open.spotify.com/track/421eObjg0DTm2qajJl5OJm - False
#   7 The Unknown - ford. - 4FXHLmzOMGLy5jFj6ctDsn - https://open.spotify.com/track/4FXHLmzOMGLy5jFj6ctDsn - False
#   8 The Unknown Soldier - The Doors - 78JYtz4yOPqAEgZZc3SBLT - https://open.spotify.com/track/78JYtz4yOPqAEgZZc3SBLT - False
#   9 The Unknown Guest - DEAN - 28WctYFXTOeQm4FTYgENyp - https://open.spotify.com/track/28WctYFXTOeQm4FTYgENyp - False

# %% [markdown]
# ### You can look for 'artist' instead of a 'song'

# %%
ide = 'madonna'

# %%
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer {}'.format(token)
}

# %%
params = (
        ('type', 'track'),
        ('limit', 5)
    )

# %%
art = requests.get("https://api.spotify.com/v1/search?q="+ ide + "&type=track", headers=headers, params=params)

# %%
art
# Out:
# <Response [200]>

# %%
print(art.json())
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=madonna&type=track&offset=0&limit=5', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0ptlfJfwGTy0Yvrk14JK1I'}, 'href': 'https://api.spotify.com/v1/albums/0ptlfJfwGTy0Yvrk14JK1I', 'id': '0ptlfJfwGTy0Yvrk14JK1I', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732090f4f6cc406e6d3c306733', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022090f4f6cc406e6d3c306733', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512090f4f6cc406e6d3c306733', 'width': 64}], 'name': "If You're Reading This It's Too Late", 'release_date': '2015-02-12', 'release_date_precision': 'day', 'total_tracks': 17, 'type': 'album', 'uri': 'spotify:album:0ptlfJfwGTy0Yvrk14JK1I'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 177840, 'explicit': True, 'external_ids': {'isrc': 'USCM51500019'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4v7SAP4KD96BFLWiCd1vF0'}, 'href': 'https://api.spotify.com/v1/tracks/4v7SAP4KD96BFLWiCd1vF0', 'id': '4v7SAP4KD96BFLWiCd1vF0', 'is_local': False, 'name': 'Madonna', 'popularity': 57, 'preview_url': None, 'track_number': 6, 'type': 'track', 'uri': 'spotify:track:4v7SAP4KD96BFLWiCd1vF0'}, {'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6tbjWDEIzxoDsBA1FuhfPW'}, 'href': 'https://api.spotify.com/v1/artists/6tbjWDEIzxoDsBA1FuhfPW', 'id': '6tbjWDEIzxoDsBA1FuhfPW', 'name': 'Madonna', 'type': 'artist', 'uri': 'spotify:artist:6tbjWDEIzxoDsBA1FuhfPW'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PT', 'PY', 'QA', 'RO', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/43lok9zd7BW5CoYkXZs7S0'}, 'href': 'https://api.spotify.c ...
